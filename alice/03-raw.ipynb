# %%
import pandas as pd
import numpy as np

# %%
# !ls train/
# Out:
# Alice_log.csv  other_user_logs

# %%
df_alice = pd.read_csv('train/Alice_log.csv')
df_alice.timestamp = pd.to_datetime(df_alice.timestamp)

# %%
df_alice
# Out:
#                 timestamp                       site
# 0     2013-02-12 16:25:10               api.bing.com
# 1     2013-02-12 16:25:11               api.bing.com
# 2     2013-02-12 16:32:10               api.bing.com
# 3     2013-02-12 16:32:11              www.google.fr
# 4     2013-02-12 16:32:24              www.google.fr
# 5     2013-02-12 16:32:25        www.info-jeunes.net
# 6     2013-02-12 16:32:25              www.google.fr
# 7     2013-02-12 16:32:26        www.info-jeunes.net
# 8     2013-02-12 16:32:27       platform.twitter.com
# 9     2013-02-12 16:32:27        www.info-jeunes.net
# 10    2013-02-12 16:32:27           www.facebook.com
# 11    2013-02-12 16:32:28        www.info-jeunes.net
# 12    2013-02-12 16:32:29                twitter.com
# 13    2013-02-12 16:32:34        www.info-jeunes.net
# 14    2013-02-12 16:32:35        www.info-jeunes.net
# 15    2013-02-12 16:32:35           www.facebook.com
# 16    2013-02-12 16:32:42        www.info-jeunes.net
# ...
