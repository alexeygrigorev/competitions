# %%
from collections import Counter
from functools import partial

import pandas as pd
import numpy as np
import scipy

from statsmodels.formula.api import ols

from tqdm import tqdm

import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML, clear_output

# %matplotlib inline

# %%
from sklearn.cross_validation import StratifiedShuffleSplit, ShuffleSplit
from sklearn.preprocessing import StandardScaler, label_binarize
from sklearn.decomposition import TruncatedSVD

# %%
from libscores import bac_metric

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD, Adam
from keras.regularizers import WeightRegularizer, l1, l2
from keras.callbacks import EarlyStopping
from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import PReLU, ELU, LeakyReLU
from keras.callbacks import EarlyStopping, Callback
# Out:
# Using Theano backend.
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
class WatchlistCallback(Callback):
    def __init__(self, watchlist, eval_metric, epoch_no=10):
        super(Callback, self).__init__()

        self.epoch_no = epoch_no
        self.X, self.y = watchlist
        self.eval_metric = eval_metric
        self.scores = []
        self.epochs = []

    def on_epoch_end(self, epoch, logs={}):
        if epoch % self.epoch_no == 0:
            y_pred = self.model.predict(self.X, verbose=0)
            score = self.eval_metric(self.y, y_pred)
            self.scores.append(score)
            self.epochs.append(epoch)

            print "score: %0.6f (epoch no %d)" % (score, epoch)  

class StatusCallback(Callback):    
    def __init__(self, epoch_total):
        super(Callback, self).__init__()
        self.progress = tqdm(total=epoch_total)
        
    def on_epoch_end(self, epoch, logs={}):
        self.progress.update(1)

    def __enter__(self): 
        return self

    def __exit__(self, type, value, traceback):
        self.progress.close()

# %%
def read_info(file_name):
    result = []
    
    for line in file(file_name):
        key, value = line.strip().split('=')
        key = key.strip()
        value = value.strip().strip("'")
        if value.isdigit():
            value = int(value)
        result.append((key, value))
    
    return dict(result)

# %%
public = read_info('data/set3_helena/helena_public.info')
public
# Out:
# {'feat_num': 27,
#  'feat_type': 'Numerical',
#  'has_categorical': 0,
#  'has_missing': 0,
#  'is_sparse': 0,
#  'label_num': 100,
#  'metric': 'bac_metric',
#  'name': 'helena',
#  'target_num': 100,
#  'target_type': 'Categorical',
#  'task': 'multiclass.classification',
#  'test_num': 18628,
#  'time_budget': 1200,
#  'train_num': 65196,
#  'usage': 'AutoML challenge 2014',
#  'valid_num': 9314}

# %%
def read_float_dense_features(file_name):
    result = list()
    for line in file(file_name):
        row = [float(f) for f in line.strip().split(' ')]
        result.append(row)
    return np.array(result)

# %%
def read_multilabels(file_name):
    result = list()
    for line in file(file_name):
        row = [f for f in line.strip().split(' ')]
        result.append(row.index('1'))
    return np.array(result)

# %%
X = read_float_dense_features('data/set3_helena/helena_train.data')
y = read_multilabels('data/set3_helena/helena_train.solution')

X_valid = read_float_dense_features('data/set3_helena/helena_valid.data')
X_test  = read_float_dense_features('data/set3_helena/helena_test.data')

print X.shape, y.shape, np.unique(y).shape
print X_valid.shape, X_test.shape
# Out:
# (65196, 27) (65196,) (100,)
# (9314, 27) (18628, 27)

# %%
classes = np.unique(y)
y_bin = label_binarize(y, classes=classes)

# %%
scaler = StandardScaler(with_mean=True, copy=False)
X = scaler.fit_transform(X)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)

# %%
train_size = 0.8
EPOCHS = 500

cv = StratifiedShuffleSplit(y, n_iter=1, train_size=train_size, random_state=1)
train, test = next(cv.__iter__())

# %%
model = Sequential()

model.add(Dense(input_dim=X.shape[1], output_dim=300, init='uniform', W_regularizer=l2(0.005))) 
model.add(Activation(PReLU()))
model.add(BatchNormalization())
# model.add(Dropout(0.01))

model.add(Dense(input_dim=300, output_dim=100, init='uniform', W_regularizer=l1(0.01))) 
model.add(Activation(PReLU())) 
model.add(BatchNormalization())
#model.add(Dropout(0.1)) 

model.add(Dense(input_dim=100, output_dim=y_bin.shape[1], init='uniform', W_regularizer=l2(0.001))) 
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam')

eval_metric = partial(bac_metric, task='multiclass.classification')
watchlist = WatchlistCallback(watchlist=(X[test], y_bin[test]), eval_metric=eval_metric, epoch_no=1)

# %%
model.fit(X[train], y_bin[train], nb_epoch=EPOCHS, batch_size=10000, 
          callbacks=[watchlist], verbose=0)
# Out:
# score: 0.032388 (epoch no 0)
# score: 0.056329 (epoch no 1)
# score: 0.065575 (epoch no 2)
# score: 0.072816 (epoch no 3)
# score: 0.076153 (epoch no 4)
# score: 0.081390 (epoch no 5)
# score: 0.087147 (epoch no 6)
# score: 0.088382 (epoch no 7)
# score: 0.089120 (epoch no 8)
# score: 0.099444 (epoch no 9)
# score: 0.107322 (epoch no 10)
# score: 0.104703 (epoch no 11)
# score: 0.113807 (epoch no 12)
# score: 0.117815 (epoch no 13)
# score: 0.118429 (epoch no 14)
# score: 0.120909 (epoch no 15)
# score: 0.131678 (epoch no 16)
# score: 0.132953 (epoch no 17)
# score: 0.126012 (epoch no 18)
# score: 0.136867 (epoch no 19)
# score: 0.142015 (epoch no 20)
# score: 0.137260 (epoch no 21)
# score: 0.145232 (epoch no 22)
# score: 0.141026 (epoch no 23)
# score: 0.145159 (epoch no 24)
# score: 0.139783 (epoch no 25)
# score: 0.155665 (epoch no 26)
# score: 0.155782 (epoch no 27)
# score: 0.161756 (epoch no 28)
# score: 0.154389 (epoch no 29)
# score: 0.160963 (epoch no 30)
# score: 0.165869 (epoch no 31)
# score: 0.170698 (epoch no 32)
# score: 0.164494 (epoch no 33)
# score: 0.167425 (epoch no 34)
# score: 0.167108 (epoch no 35)
# score: 0.170011 (epoch no 36)
# score: 0.174667 (epoch no 37)
# score: 0.176274 (epoch no 38)
# score: 0.170846 (epoch no 39)
# score: 0.183081 (epoch no 40)
# score: 0.176980 (epoch no 41)
# score: 0.173791 (epoch no 42)
# score: 0.185332 (epoch no 43)
# score: 0.170241 (epoch no 44)
# score: 0.176217 (epoch no 45)
# score: 0.181215 (epoch no 46)
# score: 0.180597 (epoch no 47)
# score: 0.185507 (epoch no 48)
# score: 0.182325 (epoch no 49)
# score: 0.184260 (epoch no 50)
# score: 0.183955 (epoch no 51)
# score: 0.183928 (epoch no 52)
# score: 0.194131 (epoch no 53)
# score: 0.191108 (epoch no 54)
# score: 0.188148 (epoch no 55)
# score: 0.194934 (epoch no 56)
# score: 0.185361 (epoch no 57)
# score: 0.188243 (epoch no 58)
# score: 0.193423 (epoch no 59)
# score: 0.185418 (epoch no 60)
# score: 0.195351 (epoch no 61)
# score: 0.189728 (epoch no 62)
# score: 0.190173 (epoch no 63)
# score: 0.195895 (epoch no 64)
# score: 0.199448 (epoch no 65)
# score: 0.190400 (epoch no 66)
# score: 0.206875 (epoch no 67)
# score: 0.192516 (epoch no 68)
# score: 0.201627 (epoch no 69)
# score: 0.201407 (epoch no 70)
# score: 0.193076 (epoch no 71)
# score: 0.200523 (epoch no 72)
# score: 0.194498 (epoch no 73)
# score: 0.209716 (epoch no 74)
# score: 0.197795 (epoch no 75)
# score: 0.204981 (epoch no 76)
# score: 0.206943 (epoch no 77)
# score: 0.187910 (epoch no 78)
# score: 0.202277 (epoch no 79)
# score: 0.201883 (epoch no 80)
# score: 0.203324 (epoch no 81)
# score: 0.198185 (epoch no 82)
# score: 0.199943 (epoch no 83)
# score: 0.208592 (epoch no 84)
# score: 0.206504 (epoch no 85)
# score: 0.204552 (epoch no 86)
# score: 0.195958 (epoch no 87)
# score: 0.195756 (epoch no 88)
# score: 0.210748 (epoch no 89)
# score: 0.205798 (epoch no 90)
# score: 0.202410 (epoch no 91)
# score: 0.197963 (epoch no 92)
# score: 0.209304 (epoch no 93)
# score: 0.207590 (epoch no 94)
# score: 0.213885 (epoch no 95)
# score: 0.209973 (epoch no 96)
# score: 0.205248 (epoch no 97)
# score: 0.199065 (epoch no 98)
# score: 0.204633 (epoch no 99)
# score: 0.205144 (epoch no 100)
# score: 0.205077 (epoch no 101)
# score: 0.200265 (epoch no 102)
# score: 0.220575 (epoch no 103)
# score: 0.211126 (epoch no 104)
# score: 0.204110 (epoch no 105)
# score: 0.207666 (epoch no 106)
# score: 0.213464 (epoch no 107)
# score: 0.210479 (epoch no 108)
# score: 0.203864 (epoch no 109)
# score: 0.208531 (epoch no 110)
# score: 0.208850 (epoch no 111)
# score: 0.207759 (epoch no 112)
# score: 0.200238 (epoch no 113)
# score: 0.209164 (epoch no 114)
# score: 0.208094 (epoch no 115)
# score: 0.208017 (epoch no 116)
# score: 0.203887 (epoch no 117)
# score: 0.207171 (epoch no 118)
# score: 0.212268 (epoch no 119)
# score: 0.210185 (epoch no 120)
# score: 0.204059 (epoch no 121)
# score: 0.211902 (epoch no 122)
# score: 0.205159 (epoch no 123)
# score: 0.211313 (epoch no 124)
# score: 0.211067 (epoch no 125)
# score: 0.210727 (epoch no 126)
# score: 0.212088 (epoch no 127)
# score: 0.207040 (epoch no 128)
# score: 0.203640 (epoch no 129)
# score: 0.218735 (epoch no 130)
# score: 0.212942 (epoch no 131)
# score: 0.211636 (epoch no 132)
# score: 0.214074 (epoch no 133)
# score: 0.216630 (epoch no 134)
# score: 0.211013 (epoch no 135)
# score: 0.204860 (epoch no 136)
# score: 0.208972 (epoch no 137)
# score: 0.205785 (epoch no 138)
# score: 0.213604 (epoch no 139)
# score: 0.210375 (epoch no 140)
# score: 0.208615 (epoch no 141)
# score: 0.209546 (epoch no 142)
# score: 0.208383 (epoch no 143)
# score: 0.213366 (epoch no 144)
# score: 0.217297 (epoch no 145)
# score: 0.212577 (epoch no 146)
# score: 0.217234 (epoch no 147)
# score: 0.204040 (epoch no 148)
# score: 0.206499 (epoch no 149)
# score: 0.209667 (epoch no 150)
# score: 0.207219 (epoch no 151)
# score: 0.211796 (epoch no 152)
# score: 0.219746 (epoch no 153)
# score: 0.219232 (epoch no 154)
# score: 0.202661 (epoch no 155)
# score: 0.209769 (epoch no 156)
# score: 0.213528 (epoch no 157)
# score: 0.214517 (epoch no 158)
# score: 0.215609 (epoch no 159)
# score: 0.212345 (epoch no 160)
# score: 0.212637 (epoch no 161)
# score: 0.210025 (epoch no 162)
# score: 0.211968 (epoch no 163)
# score: 0.225168 (epoch no 164)
# score: 0.218267 (epoch no 165)
# score: 0.209089 (epoch no 166)
# score: 0.214885 (epoch no 167)
# score: 0.213307 (epoch no 168)
# score: 0.213638 (epoch no 169)
# score: 0.218821 (epoch no 170)
# score: 0.212212 (epoch no 171)
# score: 0.219815 (epoch no 172)
# score: 0.215382 (epoch no 173)
# score: 0.219117 (epoch no 174)
# score: 0.210519 (epoch no 175)
# score: 0.209826 (epoch no 176)
# score: 0.208877 (epoch no 177)
# score: 0.210899 (epoch no 178)
# score: 0.211628 (epoch no 179)
# score: 0.211229 (epoch no 180)
# score: 0.216058 (epoch no 181)
# score: 0.221069 (epoch no 182)
# score: 0.214104 (epoch no 183)
# score: 0.218611 (epoch no 184)
# score: 0.218820 (epoch no 185)
# score: 0.210099 (epoch no 186)
# score: 0.213234 (epoch no 187)
# score: 0.209544 (epoch no 188)
# score: 0.215359 (epoch no 189)
# score: 0.229388 (epoch no 190)
# score: 0.210025 (epoch no 191)
# score: 0.222313 (epoch no 192)
# score: 0.211826 (epoch no 193)
# score: 0.213476 (epoch no 194)
# score: 0.212680 (epoch no 195)
# score: 0.215247 (epoch no 196)
# score: 0.216501 (epoch no 197)
# score: 0.212886 (epoch no 198)
# score: 0.210221 (epoch no 199)
# score: 0.215722 (epoch no 200)
# score: 0.211683 (epoch no 201)
# score: 0.213983 (epoch no 202)
# score: 0.220144 (epoch no 203)
# score: 0.209921 (epoch no 204)
# score: 0.214007 (epoch no 205)
# score: 0.210098 (epoch no 206)
# score: 0.217741 (epoch no 207)
# score: 0.208727 (epoch no 208)
# score: 0.214638 (epoch no 209)
# score: 0.214995 (epoch no 210)
# score: 0.219628 (epoch no 211)
# score: 0.215046 (epoch no 212)
# score: 0.217716 (epoch no 213)
# score: 0.214452 (epoch no 214)
# score: 0.213199 (epoch no 215)
# score: 0.216781 (epoch no 216)
# score: 0.216834 (epoch no 217)
# score: 0.217158 (epoch no 218)
# score: 0.219633 (epoch no 219)
# score: 0.216184 (epoch no 220)
# score: 0.213345 (epoch no 221)
# score: 0.219853 (epoch no 222)
# score: 0.212199 (epoch no 223)
# score: 0.203223 (epoch no 224)
# score: 0.211389 (epoch no 225)
# score: 0.214794 (epoch no 226)
# score: 0.214033 (epoch no 227)
# score: 0.211984 (epoch no 228)
# score: 0.208113 (epoch no 229)
# score: 0.220857 (epoch no 230)
# score: 0.210973 (epoch no 231)
# score: 0.215190 (epoch no 232)
# score: 0.217545 (epoch no 233)
# score: 0.206572 (epoch no 234)
# score: 0.213801 (epoch no 235)
# score: 0.212864 (epoch no 236)
# score: 0.214583 (epoch no 237)
# score: 0.216989 (epoch no 238)
# score: 0.210896 (epoch no 239)
# score: 0.208303 (epoch no 240)
# score: 0.216230 (epoch no 241)
# score: 0.211400 (epoch no 242)
# score: 0.223570 (epoch no 243)
# score: 0.215571 (epoch no 244)
# score: 0.207669 (epoch no 245)
# score: 0.214961 (epoch no 246)
# score: 0.215749 (epoch no 247)
# score: 0.210996 (epoch no 248)
# score: 0.212174 (epoch no 249)
# score: 0.212966 (epoch no 250)
# score: 0.210405 (epoch no 251)
# score: 0.214143 (epoch no 252)
# score: 0.223226 (epoch no 253)
# score: 0.210960 (epoch no 254)
# score: 0.219169 (epoch no 255)
# score: 0.221287 (epoch no 256)
# score: 0.213710 (epoch no 257)
# score: 0.209252 (epoch no 258)
# score: 0.210329 (epoch no 259)
# score: 0.220887 (epoch no 260)
# score: 0.211485 (epoch no 261)
# score: 0.217616 (epoch no 262)
# score: 0.217385 (epoch no 263)
# score: 0.217908 (epoch no 264)
# score: 0.217105 (epoch no 265)
# score: 0.212133 (epoch no 266)
# score: 0.221005 (epoch no 267)
# score: 0.211325 (epoch no 268)
# score: 0.219399 (epoch no 269)
# score: 0.216689 (epoch no 270)
# score: 0.220199 (epoch no 271)
# score: 0.222019 (epoch no 272)
# score: 0.228540 (epoch no 273)
# score: 0.217986 (epoch no 274)
# score: 0.218894 (epoch no 275)
# score: 0.216208 (epoch no 276)
# score: 0.212666 (epoch no 277)
# score: 0.211793 (epoch no 278)
# score: 0.218053 (epoch no 279)
# score: 0.210163 (epoch no 280)
# score: 0.220081 (epoch no 281)
# score: 0.208721 (epoch no 282)
# score: 0.209444 (epoch no 283)
# score: 0.209132 (epoch no 284)
# score: 0.216600 (epoch no 285)
# score: 0.217449 (epoch no 286)
# score: 0.219545 (epoch no 287)
# score: 0.213376 (epoch no 288)
# score: 0.212819 (epoch no 289)
# score: 0.212024 (epoch no 290)
# score: 0.222194 (epoch no 291)
# score: 0.213822 (epoch no 292)
# score: 0.213871 (epoch no 293)
# score: 0.209880 (epoch no 294)
# score: 0.218772 (epoch no 295)
# score: 0.221743 (epoch no 296)
# score: 0.219480 (epoch no 297)
# score: 0.211596 (epoch no 298)
# score: 0.207574 (epoch no 299)
# score: 0.215286 (epoch no 300)
# score: 0.219742 (epoch no 301)
# score: 0.213683 (epoch no 302)
# score: 0.210473 (epoch no 303)
# score: 0.211310 (epoch no 304)
# score: 0.207650 (epoch no 305)
# score: 0.206978 (epoch no 306)
# score: 0.218713 (epoch no 307)
# score: 0.222326 (epoch no 308)
# score: 0.211849 (epoch no 309)
# score: 0.215815 (epoch no 310)
# score: 0.216574 (epoch no 311)
# score: 0.216723 (epoch no 312)
# score: 0.214644 (epoch no 313)
# score: 0.214314 (epoch no 314)
# score: 0.228890 (epoch no 315)
# score: 0.224679 (epoch no 316)
# score: 0.217494 (epoch no 317)
# score: 0.221614 (epoch no 318)
# score: 0.211061 (epoch no 319)
# score: 0.211380 (epoch no 320)
# score: 0.205230 (epoch no 321)
# score: 0.217767 (epoch no 322)
# score: 0.220320 (epoch no 323)
# score: 0.215569 (epoch no 324)
# score: 0.221187 (epoch no 325)
# score: 0.214682 (epoch no 326)
# score: 0.222681 (epoch no 327)
# score: 0.217173 (epoch no 328)
# score: 0.218605 (epoch no 329)
# score: 0.214951 (epoch no 330)
# score: 0.218266 (epoch no 331)
# score: 0.213653 (epoch no 332)
# score: 0.211646 (epoch no 333)
# score: 0.217248 (epoch no 334)
# score: 0.218111 (epoch no 335)
# score: 0.211424 (epoch no 336)
# score: 0.213528 (epoch no 337)
# score: 0.218529 (epoch no 338)
# score: 0.219092 (epoch no 339)
# score: 0.205619 (epoch no 340)
# score: 0.216984 (epoch no 341)
# score: 0.218823 (epoch no 342)
# score: 0.210854 (epoch no 343)
# score: 0.211403 (epoch no 344)
# score: 0.211353 (epoch no 345)
# score: 0.209537 (epoch no 346)
# score: 0.217749 (epoch no 347)
# score: 0.214220 (epoch no 348)
# score: 0.217997 (epoch no 349)
# score: 0.215314 (epoch no 350)
# score: 0.211842 (epoch no 351)
# score: 0.208960 (epoch no 352)
# score: 0.214872 (epoch no 353)
# score: 0.223211 (epoch no 354)
# score: 0.213405 (epoch no 355)
# score: 0.216901 (epoch no 356)
# score: 0.214302 (epoch no 357)
# score: 0.212268 (epoch no 358)
# score: 0.221885 (epoch no 359)
# score: 0.212938 (epoch no 360)
# score: 0.214709 (epoch no 361)
# score: 0.216774 (epoch no 362)
# score: 0.215024 (epoch no 363)
# score: 0.221089 (epoch no 364)
# score: 0.216249 (epoch no 365)
# score: 0.209596 (epoch no 366)
# score: 0.219908 (epoch no 367)
# score: 0.225416 (epoch no 368)
# score: 0.213983 (epoch no 369)
# score: 0.221817 (epoch no 370)
# score: 0.210252 (epoch no 371)
# score: 0.215190 (epoch no 372)
# score: 0.209311 (epoch no 373)
# score: 0.208158 (epoch no 374)
# score: 0.208208 (epoch no 375)
# score: 0.223509 (epoch no 376)
# score: 0.216014 (epoch no 377)
# score: 0.221199 (epoch no 378)
# score: 0.218645 (epoch no 379)
# score: 0.212528 (epoch no 380)
# score: 0.221960 (epoch no 381)
# score: 0.212636 (epoch no 382)
# score: 0.221615 (epoch no 383)
# score: 0.208436 (epoch no 384)
# score: 0.215615 (epoch no 385)
# score: 0.216725 (epoch no 386)
# score: 0.215297 (epoch no 387)
# score: 0.213438 (epoch no 388)
# score: 0.215551 (epoch no 389)
# score: 0.210028 (epoch no 390)
# score: 0.210306 (epoch no 391)
# score: 0.210512 (epoch no 392)
# score: 0.212652 (epoch no 393)
# score: 0.212984 (epoch no 394)
# score: 0.214408 (epoch no 395)
# score: 0.218869 (epoch no 396)
# score: 0.217646 (epoch no 397)
# score: 0.208286 (epoch no 398)
# score: 0.228004 (epoch no 399)
# score: 0.212176 (epoch no 400)
# score: 0.214035 (epoch no 401)
# score: 0.216184 (epoch no 402)
# score: 0.217436 (epoch no 403)
# score: 0.219922 (epoch no 404)
# score: 0.207360 (epoch no 405)
# score: 0.211597 (epoch no 406)
# score: 0.217432 (epoch no 407)
# score: 0.220665 (epoch no 408)
# score: 0.217034 (epoch no 409)
# score: 0.213979 (epoch no 410)
# score: 0.208999 (epoch no 411)
# score: 0.213427 (epoch no 412)
# score: 0.210770 (epoch no 413)
# score: 0.221031 (epoch no 414)
# score: 0.213867 (epoch no 415)
# score: 0.221362 (epoch no 416)
# score: 0.215036 (epoch no 417)
# score: 0.219288 (epoch no 418)
# score: 0.217017 (epoch no 419)
# score: 0.212608 (epoch no 420)
# score: 0.221719 (epoch no 421)
# score: 0.220589 (epoch no 422)
# score: 0.214695 (epoch no 423)
# score: 0.209227 (epoch no 424)
# score: 0.214390 (epoch no 425)
# score: 0.213348 (epoch no 426)
# score: 0.219202 (epoch no 427)
# score: 0.205856 (epoch no 428)
# score: 0.216542 (epoch no 429)
# score: 0.217575 (epoch no 430)
# score: 0.214931 (epoch no 431)
# score: 0.216654 (epoch no 432)
# score: 0.212327 (epoch no 433)
# score: 0.210657 (epoch no 434)
# score: 0.214733 (epoch no 435)
# score: 0.208766 (epoch no 436)
# score: 0.219966 (epoch no 437)
# score: 0.214082 (epoch no 438)
# score: 0.213740 (epoch no 439)
# score: 0.219579 (epoch no 440)
# score: 0.213002 (epoch no 441)
# score: 0.218771 (epoch no 442)
# score: 0.208768 (epoch no 443)
# score: 0.212915 (epoch no 444)
# score: 0.220545 (epoch no 445)
# score: 0.223261 (epoch no 446)
# score: 0.215970 (epoch no 447)
# score: 0.215430 (epoch no 448)
# score: 0.212096 (epoch no 449)
# score: 0.218155 (epoch no 450)
# score: 0.212137 (epoch no 451)
# score: 0.222083 (epoch no 452)
# score: 0.214193 (epoch no 453)
# score: 0.219073 (epoch no 454)
# score: 0.215249 (epoch no 455)
# score: 0.207293 (epoch no 456)
# score: 0.204565 (epoch no 457)
# score: 0.218486 (epoch no 458)
# score: 0.222761 (epoch no 459)
# score: 0.207823 (epoch no 460)
# score: 0.227051 (epoch no 461)
# score: 0.219126 (epoch no 462)
# score: 0.217907 (epoch no 463)
# score: 0.213270 (epoch no 464)
# score: 0.215024 (epoch no 465)
# score: 0.219214 (epoch no 466)
# score: 0.215976 (epoch no 467)
# score: 0.209426 (epoch no 468)
# score: 0.218081 (epoch no 469)
# score: 0.222575 (epoch no 470)
# score: 0.217395 (epoch no 471)
# score: 0.220377 (epoch no 472)
# score: 0.210758 (epoch no 473)
# score: 0.208547 (epoch no 474)
# score: 0.225430 (epoch no 475)
# score: 0.211480 (epoch no 476)
# score: 0.218168 (epoch no 477)
# score: 0.215688 (epoch no 478)
# score: 0.220979 (epoch no 479)
# score: 0.204592 (epoch no 480)
# score: 0.215004 (epoch no 481)
# score: 0.218094 (epoch no 482)
# score: 0.214795 (epoch no 483)
# score: 0.215986 (epoch no 484)
# score: 0.212490 (epoch no 485)
# score: 0.210548 (epoch no 486)
# score: 0.218422 (epoch no 487)
# score: 0.218943 (epoch no 488)
# score: 0.218323 (epoch no 489)
# score: 0.208442 (epoch no 490)
# score: 0.209266 (epoch no 491)
# score: 0.207269 (epoch no 492)
# score: 0.218394 (epoch no 493)
# score: 0.208654 (epoch no 494)
# score: 0.220363 (epoch no 495)
# score: 0.215242 (epoch no 496)
# score: 0.218747 (epoch no 497)
# score: 0.212401 (epoch no 498)
# score: 0.210779 (epoch no 499)

# %%
model = Sequential()

model.add(Dense(input_dim=X_input.shape[1], output_dim=300, init='uniform')) 
model.add(Activation('linear')) 
model.add(Dropout(0.01)) 

model.add(Dense(input_dim=300, output_dim=100, init='uniform')) 
model.add(Activation('tanh')) 
model.add(Dropout(0.1)) 

model.add(Dense(input_dim=100, output_dim=y_bin.shape[1], init='uniform')) 
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam')

EPOCHS=224

with StatusCallback(epoch_total=EPOCHS) as status:
    model.fit(X_input, y_bin, nb_epoch=EPOCHS, batch_size=10000, callbacks=[status], verbose=0)

# %%
y_valid_score = model.predict(X_valid)
y_test_score = model.predict(X_test)

# %%
np.savetxt('submission/helena_valid.predict', y_valid_score, fmt='%0.10f')
np.savetxt('submission/helena_test.predict', y_test_score, fmt='%0.10f')
