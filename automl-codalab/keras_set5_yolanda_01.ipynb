# %%
from collections import Counter
from functools import partial

import pandas as pd
import numpy as np
import scipy

from statsmodels.formula.api import ols

from tqdm import tqdm

import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML, clear_output

# %matplotlib inline

# %%
from sklearn.cross_validation import StratifiedShuffleSplit, ShuffleSplit

# %%
from libscores import r2_metric

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD, Adam
from keras.regularizers import WeightRegularizer, l1, l2
from keras.callbacks import EarlyStopping
from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import PReLU, ELU, LeakyReLU
from keras.callbacks import EarlyStopping, Callback

# %%
class WatchlistCallback(Callback):
    def __init__(self, watchlist, eval_metric, epoch_no=10):
        super(Callback, self).__init__()

        self.epoch_no = epoch_no
        self.X, self.y = watchlist
        self.eval_metric = eval_metric
        self.scores = []
        self.epochs = []

    def on_epoch_end(self, epoch, logs={}):
        if epoch % self.epoch_no == 0:
            y_pred = self.model.predict(self.X, verbose=0)
            score = self.eval_metric(self.y, y_pred)
            self.scores.append(score)
            self.epochs.append(epoch)

            print "score: %0.6f (epoch no %d)" % (score, epoch)  

class StatusCallback(Callback):    
    def __init__(self, epoch_total):
        super(Callback, self).__init__()
        self.progress = tqdm(total=epoch_total)
        
    def on_epoch_end(self, epoch, logs={}):
        self.progress.update(1)

    def __enter__(self): 
        return self

    def __exit__(self, type, value, traceback):
        self.progress.close()

# %%
def read_info(file_name):
    result = []
    
    for line in file(file_name):
        key, value = line.strip().split('=')
        key = key.strip()
        value = value.strip().strip("'")
        if value.isdigit():
            value = int(value)
        result.append((key, value))
    
    return dict(result)

# %%
public = read_info('data/set5_yolanda/yolanda_public.info')
public
# Out:
# {'feat_num': 100,
#  'feat_type': 'Numerical',
#  'has_categorical': 0,
#  'has_missing': 0,
#  'is_sparse': 0,
#  'label_num': 0,
#  'metric': 'r2_metric',
#  'name': 'yolanda',
#  'target_num': 1,
#  'target_type': 'Numerical',
#  'task': 'regression',
#  'test_num': 30000,
#  'time_budget': 1200,
#  'train_num': 400000,
#  'usage': 'AutoML challenge 2014',
#  'valid_num': 30000}

# %%
def read_float_dense_features(file_name):
    result = list()
    for line in file(file_name):
        row = [float(f) for f in line.strip().split(' ')]
        result.append(row)
    return np.array(result)

# %%
def read_numeric_labels(file_name):
    return np.fromfile(file_name, sep='\n', dtype=np.float)

# %%
data = 'data/set5_yolanda/yolanda_'
X = read_float_dense_features(data + 'train.data')

X_valid = read_float_dense_features(data + 'valid.data')
X_test  = read_float_dense_features(data + 'test.data')

print X.shape, y.shape
print X_valid.shape, X_test.shape
# Out:
# (400000, 100) (400000,)
# (30000, 100) (30000, 100)

# %%
y = read_numeric_labels(data + 'train.solution')

# %%
y_mean = y.mean()
y = y.reshape(-1, 1) - y_mean

# %%
scaler = StandardScaler(with_mean=True, copy=False)
X = scaler.fit_transform(X)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)

# %%
train_size = 0.8
EPOCHS = 500

cv = ShuffleSplit(len(y), n_iter=1, train_size=train_size, random_state=1)
train, test = next(cv.__iter__())

# %%
model = Sequential()

model.add(Dense(input_dim=100, output_dim=100, init='uniform'))
model.add(Activation('tanh'))

model.add(Dense(input_dim=100, output_dim=1, init='uniform'))
model.add(Activation('linear'))

model.compile(loss="mean_squared_error", optimizer="sgd") 

def eval_model(solution, prediction):
    return r2_metric(solution + y_mean, prediction + y_mean, task='regression')

watchlist = WatchlistCallback(watchlist=(X[test], y[test]), eval_metric=eval_model, epoch_no=1)

# %%
model.fit(X[train], y[train], nb_epoch=EPOCHS, batch_size=100000, callbacks=[watchlist], verbose=0)
# Out:
# score: 0.011256 (epoch no 0)
# score: 0.027801 (epoch no 1)
# score: 0.055176 (epoch no 2)
# score: 0.090169 (epoch no 3)
# score: 0.124938 (epoch no 4)
# score: 0.153628 (epoch no 5)
# score: 0.176280 (epoch no 6)
# score: 0.193668 (epoch no 7)
# score: 0.207134 (epoch no 8)
# score: 0.218070 (epoch no 9)
# score: 0.227016 (epoch no 10)
# score: 0.234635 (epoch no 11)
# score: 0.240987 (epoch no 12)
# score: 0.246410 (epoch no 13)
# score: 0.251111 (epoch no 14)
# score: 0.255231 (epoch no 15)
# score: 0.258510 (epoch no 16)
# score: 0.261535 (epoch no 17)
# score: 0.264075 (epoch no 18)
# score: 0.266127 (epoch no 19)
# score: 0.268166 (epoch no 20)
# score: 0.270033 (epoch no 21)
# score: 0.271641 (epoch no 22)
# score: 0.273271 (epoch no 23)
# score: 0.274810 (epoch no 24)
# score: 0.276066 (epoch no 25)
# score: 0.277246 (epoch no 26)
# score: 0.278255 (epoch no 27)
# score: 0.279304 (epoch no 28)
# score: 0.280467 (epoch no 29)
# score: 0.281431 (epoch no 30)
# score: 0.282244 (epoch no 31)
# score: 0.283230 (epoch no 32)
# score: 0.284066 (epoch no 33)
# score: 0.284725 (epoch no 34)
# score: 0.285652 (epoch no 35)
# score: 0.286502 (epoch no 36)
# score: 0.287125 (epoch no 37)
# score: 0.287797 (epoch no 38)
# score: 0.288460 (epoch no 39)
# score: 0.289128 (epoch no 40)
# score: 0.289746 (epoch no 41)
# score: 0.290397 (epoch no 42)
# score: 0.290874 (epoch no 43)
# score: 0.291668 (epoch no 44)
# score: 0.292064 (epoch no 45)
# score: 0.292667 (epoch no 46)
# score: 0.293178 (epoch no 47)
# score: 0.293577 (epoch no 48)
# score: 0.294203 (epoch no 49)
# score: 0.294785 (epoch no 50)
# score: 0.295084 (epoch no 51)
# score: 0.295500 (epoch no 52)
# score: 0.296081 (epoch no 53)
# score: 0.296420 (epoch no 54)
# score: 0.296830 (epoch no 55)
# score: 0.297342 (epoch no 56)
# score: 0.297656 (epoch no 57)
# score: 0.298099 (epoch no 58)
# score: 0.298515 (epoch no 59)
# score: 0.298944 (epoch no 60)
# score: 0.299191 (epoch no 61)
# score: 0.299580 (epoch no 62)
# score: 0.300087 (epoch no 63)
# score: 0.300271 (epoch no 64)
# score: 0.300704 (epoch no 65)
# score: 0.300987 (epoch no 66)
# score: 0.301416 (epoch no 67)
# score: 0.301607 (epoch no 68)
# score: 0.302028 (epoch no 69)
# score: 0.302395 (epoch no 70)
# score: 0.302622 (epoch no 71)
# score: 0.302986 (epoch no 72)
# score: 0.303203 (epoch no 73)
# score: 0.303469 (epoch no 74)
# score: 0.303746 (epoch no 75)
# score: 0.304101 (epoch no 76)
# score: 0.304358 (epoch no 77)
# score: 0.304606 (epoch no 78)
# score: 0.304897 (epoch no 79)
# score: 0.305088 (epoch no 80)
# score: 0.305452 (epoch no 81)
# score: 0.305761 (epoch no 82)
# score: 0.305973 (epoch no 83)
# score: 0.306095 (epoch no 84)
# score: 0.306431 (epoch no 85)
# score: 0.306891 (epoch no 86)
# score: 0.306968 (epoch no 87)
# score: 0.307283 (epoch no 88)
# score: 0.307734 (epoch no 89)
# score: 0.307937 (epoch no 90)
# score: 0.308074 (epoch no 91)
# score: 0.308418 (epoch no 92)
# score: 0.308576 (epoch no 93)
# score: 0.308912 (epoch no 94)
# score: 0.309109 (epoch no 95)
# score: 0.309312 (epoch no 96)
# score: 0.309440 (epoch no 97)
# score: 0.309802 (epoch no 98)
# score: 0.310052 (epoch no 99)
# score: 0.310262 (epoch no 100)
# score: 0.310304 (epoch no 101)
# score: 0.310418 (epoch no 102)
# score: 0.310670 (epoch no 103)
# score: 0.311130 (epoch no 104)
# score: 0.311248 (epoch no 105)
# score: 0.311373 (epoch no 106)
# score: 0.311911 (epoch no 107)
# score: 0.312016 (epoch no 108)
# score: 0.312183 (epoch no 109)
# score: 0.312432 (epoch no 110)
# score: 0.312543 (epoch no 111)
# score: 0.312961 (epoch no 112)
# score: 0.312961 (epoch no 113)
# score: 0.313449 (epoch no 114)
# score: 0.313620 (epoch no 115)
# score: 0.313654 (epoch no 116)
# score: 0.313811 (epoch no 117)
# score: 0.314124 (epoch no 118)
# score: 0.314453 (epoch no 119)
# score: 0.314509 (epoch no 120)
# score: 0.314819 (epoch no 121)
# score: 0.315006 (epoch no 122)
# score: 0.315107 (epoch no 123)
# score: 0.315444 (epoch no 124)
# score: 0.315693 (epoch no 125)
# score: 0.315740 (epoch no 126)
# score: 0.315995 (epoch no 127)
# score: 0.316170 (epoch no 128)
# score: 0.316138 (epoch no 129)
# score: 0.316578 (epoch no 130)
# score: 0.316674 (epoch no 131)
# score: 0.316678 (epoch no 132)
# score: 0.316991 (epoch no 133)
# score: 0.317241 (epoch no 134)
# score: 0.317393 (epoch no 135)
# score: 0.317652 (epoch no 136)
# score: 0.317899 (epoch no 137)
# score: 0.318091 (epoch no 138)
# score: 0.318220 (epoch no 139)
# score: 0.318336 (epoch no 140)
# score: 0.318564 (epoch no 141)
# score: 0.318718 (epoch no 142)
# score: 0.318886 (epoch no 143)
# score: 0.319020 (epoch no 144)
# score: 0.319331 (epoch no 145)
# score: 0.319387 (epoch no 146)
# score: 0.319757 (epoch no 147)
# score: 0.319755 (epoch no 148)
# score: 0.320151 (epoch no 149)
# score: 0.320226 (epoch no 150)
# score: 0.320321 (epoch no 151)
# score: 0.320307 (epoch no 152)
# score: 0.320839 (epoch no 153)
# score: 0.320675 (epoch no 154)
# score: 0.321241 (epoch no 155)
# score: 0.321292 (epoch no 156)
# score: 0.321296 (epoch no 157)
# score: 0.321680 (epoch no 158)
# score: 0.322018 (epoch no 159)
# score: 0.322189 (epoch no 160)
# score: 0.322169 (epoch no 161)
# score: 0.322366 (epoch no 162)
# score: 0.322630 (epoch no 163)
# score: 0.322785 (epoch no 164)
# score: 0.322893 (epoch no 165)
# score: 0.323075 (epoch no 166)
# score: 0.323329 (epoch no 167)
# score: 0.323335 (epoch no 168)
# score: 0.323674 (epoch no 169)
# score: 0.323721 (epoch no 170)
# score: 0.323943 (epoch no 171)
# score: 0.324126 (epoch no 172)
# score: 0.324252 (epoch no 173)
# score: 0.324553 (epoch no 174)
# score: 0.324580 (epoch no 175)
# score: 0.324765 (epoch no 176)
# score: 0.325001 (epoch no 177)
# score: 0.325076 (epoch no 178)
# score: 0.325272 (epoch no 179)
# score: 0.325396 (epoch no 180)
# score: 0.325582 (epoch no 181)
# score: 0.325819 (epoch no 182)
# score: 0.325866 (epoch no 183)
# score: 0.325858 (epoch no 184)
# score: 0.326318 (epoch no 185)
# score: 0.326480 (epoch no 186)
# score: 0.326502 (epoch no 187)
# score: 0.326784 (epoch no 188)
# score: 0.326779 (epoch no 189)
# score: 0.326948 (epoch no 190)
# score: 0.326824 (epoch no 191)
# score: 0.327231 (epoch no 192)
# score: 0.327292 (epoch no 193)
# score: 0.327603 (epoch no 194)
# score: 0.327315 (epoch no 195)
# score: 0.327930 (epoch no 196)
# score: 0.327945 (epoch no 197)
# score: 0.328280 (epoch no 198)
# score: 0.328389 (epoch no 199)
# score: 0.328506 (epoch no 200)
# score: 0.328488 (epoch no 201)
# score: 0.328611 (epoch no 202)
# score: 0.328794 (epoch no 203)
# score: 0.329059 (epoch no 204)
# score: 0.328523 (epoch no 205)
# score: 0.329173 (epoch no 206)
# score: 0.329420 (epoch no 207)
# score: 0.329207 (epoch no 208)
# score: 0.329725 (epoch no 209)
# score: 0.329809 (epoch no 210)
# score: 0.329597 (epoch no 211)
# score: 0.330139 (epoch no 212)
# score: 0.330281 (epoch no 213)
# score: 0.330398 (epoch no 214)
# score: 0.330534 (epoch no 215)
# score: 0.330598 (epoch no 216)
# score: 0.330773 (epoch no 217)
# score: 0.330808 (epoch no 218)
# score: 0.330811 (epoch no 219)
# score: 0.331210 (epoch no 220)
# score: 0.331477 (epoch no 221)
# score: 0.331609 (epoch no 222)
# score: 0.331841 (epoch no 223)
# score: 0.331834 (epoch no 224)
# score: 0.332012 (epoch no 225)
# score: 0.331718 (epoch no 226)
# score: 0.332301 (epoch no 227)
# score: 0.332307 (epoch no 228)
# score: 0.332543 (epoch no 229)
# score: 0.332761 (epoch no 230)
# score: 0.332671 (epoch no 231)
# score: 0.333057 (epoch no 232)
# score: 0.333080 (epoch no 233)
# score: 0.333054 (epoch no 234)
# score: 0.333136 (epoch no 235)
# score: 0.333193 (epoch no 236)
# score: 0.333581 (epoch no 237)
# score: 0.333456 (epoch no 238)
# score: 0.333659 (epoch no 239)
# score: 0.333776 (epoch no 240)
# score: 0.334054 (epoch no 241)
# score: 0.334263 (epoch no 242)
# score: 0.334113 (epoch no 243)
# score: 0.334496 (epoch no 244)
# score: 0.334193 (epoch no 245)
# score: 0.334526 (epoch no 246)
# score: 0.334865 (epoch no 247)
# score: 0.334468 (epoch no 248)
# score: 0.334940 (epoch no 249)
# score: 0.335053 (epoch no 250)
# score: 0.334963 (epoch no 251)
# score: 0.335216 (epoch no 252)
# score: 0.335245 (epoch no 253)
# score: 0.335561 (epoch no 254)
# score: 0.335106 (epoch no 255)
# score: 0.335719 (epoch no 256)
# score: 0.335798 (epoch no 257)
# score: 0.336148 (epoch no 258)
# score: 0.335927 (epoch no 259)
# score: 0.336077 (epoch no 260)
# score: 0.336379 (epoch no 261)
# score: 0.336709 (epoch no 262)
# score: 0.336559 (epoch no 263)
# score: 0.336459 (epoch no 264)
# score: 0.336571 (epoch no 265)
# score: 0.336546 (epoch no 266)
# score: 0.336705 (epoch no 267)
# score: 0.336389 (epoch no 268)
# score: 0.336686 (epoch no 269)
# score: 0.336607 (epoch no 270)
# score: 0.336944 (epoch no 271)
# score: 0.337488 (epoch no 272)
# score: 0.337702 (epoch no 273)
# score: 0.337443 (epoch no 274)
# score: 0.337625 (epoch no 275)
# score: 0.337852 (epoch no 276)
# score: 0.338054 (epoch no 277)
# score: 0.338008 (epoch no 278)
# score: 0.337567 (epoch no 279)
# score: 0.338055 (epoch no 280)
# score: 0.338017 (epoch no 281)
# score: 0.338242 (epoch no 282)
# score: 0.338131 (epoch no 283)
# score: 0.338570 (epoch no 284)
# score: 0.338599 (epoch no 285)
# score: 0.338551 (epoch no 286)
# score: 0.339004 (epoch no 287)
# score: 0.338928 (epoch no 288)
# score: 0.339034 (epoch no 289)
# score: 0.338720 (epoch no 290)
# score: 0.339069 (epoch no 291)
# score: 0.338930 (epoch no 292)
# score: 0.339337 (epoch no 293)
# score: 0.339780 (epoch no 294)
# score: 0.339658 (epoch no 295)
# score: 0.339714 (epoch no 296)
# score: 0.339103 (epoch no 297)
# score: 0.339728 (epoch no 298)
# score: 0.340093 (epoch no 299)
# score: 0.339764 (epoch no 300)
# score: 0.339221 (epoch no 301)
# score: 0.339048 (epoch no 302)
# score: 0.339909 (epoch no 303)
# score: 0.340532 (epoch no 304)
# score: 0.340454 (epoch no 305)
# score: 0.340654 (epoch no 306)
# score: 0.340836 (epoch no 307)
# score: 0.341025 (epoch no 308)
# score: 0.340452 (epoch no 309)
# score: 0.340391 (epoch no 310)
# score: 0.340813 (epoch no 311)
# score: 0.339528 (epoch no 312)
# score: 0.340414 (epoch no 313)
# score: 0.340180 (epoch no 314)
# score: 0.338949 (epoch no 315)
# score: 0.334712 (epoch no 316)
# score: 0.331476 (epoch no 317)
# score: 0.332499 (epoch no 318)
# score: 0.330938 (epoch no 319)
# score: 0.330224 (epoch no 320)
# score: 0.326049 (epoch no 321)
# score: 0.328037 (epoch no 322)
# score: 0.332591 (epoch no 323)
# score: 0.337637 (epoch no 324)
# score: 0.339269 (epoch no 325)
# score: 0.340410 (epoch no 326)
# score: 0.339320 (epoch no 327)
# score: 0.339069 (epoch no 328)
# score: 0.339827 (epoch no 329)
# score: 0.341968 (epoch no 330)
# score: 0.342406 (epoch no 331)
# score: 0.342415 (epoch no 332)
# score: 0.342678 (epoch no 333)
# score: 0.342079 (epoch no 334)
# score: 0.341700 (epoch no 335)
# score: 0.341900 (epoch no 336)
# score: 0.342919 (epoch no 337)
# score: 0.343147 (epoch no 338)
# score: 0.343029 (epoch no 339)
# score: 0.341047 (epoch no 340)
# score: 0.340908 (epoch no 341)
# score: 0.342531 (epoch no 342)
# score: 0.339197 (epoch no 343)
# score: 0.337778 (epoch no 344)
# score: 0.330584 (epoch no 345)
# score: 0.325465 (epoch no 346)
# score: 0.322563 (epoch no 347)
# score: 0.326670 (epoch no 348)
# score: 0.332651 (epoch no 349)
# score: 0.337103 (epoch no 350)
# score: 0.340765 (epoch no 351)
# score: 0.341962 (epoch no 352)
# score: 0.341756 (epoch no 353)
# score: 0.343612 (epoch no 354)
# score: 0.343795 (epoch no 355)
# score: 0.344238 (epoch no 356)
# score: 0.343459 (epoch no 357)
# score: 0.343994 (epoch no 358)
# score: 0.344493 (epoch no 359)
# score: 0.344185 (epoch no 360)
# score: 0.344471 (epoch no 361)
# score: 0.344564 (epoch no 362)
# score: 0.343970 (epoch no 363)
# score: 0.344357 (epoch no 364)
# score: 0.343974 (epoch no 365)
# score: 0.344471 (epoch no 366)
# score: 0.343888 (epoch no 367)
# score: 0.343454 (epoch no 368)
# score: 0.343356 (epoch no 369)
# score: 0.340266 (epoch no 370)
# score: 0.337173 (epoch no 371)
# score: 0.331658 (epoch no 372)
# score: 0.322025 (epoch no 373)
# score: 0.318289 (epoch no 374)
# score: 0.328741 (epoch no 375)
# score: 0.330460 (epoch no 376)
# score: 0.328170 (epoch no 377)
# score: 0.334170 (epoch no 378)
# score: 0.337578 (epoch no 379)
# score: 0.338356 (epoch no 380)
# score: 0.341518 (epoch no 381)
# score: 0.342679 (epoch no 382)
# score: 0.344453 (epoch no 383)
# score: 0.345381 (epoch no 384)
# score: 0.345273 (epoch no 385)
# score: 0.344590 (epoch no 386)
# score: 0.344714 (epoch no 387)
# score: 0.343358 (epoch no 388)
# score: 0.342455 (epoch no 389)
# score: 0.341485 (epoch no 390)
# score: 0.343899 (epoch no 391)
# score: 0.345490 (epoch no 392)
# score: 0.345819 (epoch no 393)
# score: 0.345580 (epoch no 394)
# score: 0.345044 (epoch no 395)
# score: 0.344096 (epoch no 396)
# score: 0.341467 (epoch no 397)
# score: 0.341179 (epoch no 398)
# score: 0.341330 (epoch no 399)
# score: 0.340452 (epoch no 400)
# score: 0.337737 (epoch no 401)
# score: 0.338165 (epoch no 402)
# score: 0.337061 (epoch no 403)
# score: 0.334195 (epoch no 404)
# score: 0.335109 (epoch no 405)
# score: 0.335971 (epoch no 406)
# score: 0.339329 (epoch no 407)
# score: 0.342513 (epoch no 408)
# score: 0.343508 (epoch no 409)
# score: 0.343206 (epoch no 410)
# score: 0.346035 (epoch no 411)
# score: 0.346399 (epoch no 412)
# score: 0.345893 (epoch no 413)
# score: 0.345670 (epoch no 414)
# score: 0.346924 (epoch no 415)
# score: 0.347354 (epoch no 416)
# score: 0.346703 (epoch no 417)
# score: 0.346304 (epoch no 418)
# score: 0.347011 (epoch no 419)
# score: 0.346338 (epoch no 420)
# score: 0.346178 (epoch no 421)
# score: 0.342949 (epoch no 422)
# score: 0.342487 (epoch no 423)
# score: 0.341242 (epoch no 424)
# score: 0.339972 (epoch no 425)
# score: 0.337057 (epoch no 426)
# score: 0.331385 (epoch no 427)
# score: 0.330484 (epoch no 428)
# score: 0.325344 (epoch no 429)
# score: 0.331301 (epoch no 430)
# score: 0.334705 (epoch no 431)
# score: 0.338231 (epoch no 432)
# score: 0.344911 (epoch no 433)
# score: 0.346107 (epoch no 434)
# score: 0.347115 (epoch no 435)
# score: 0.347508 (epoch no 436)
# score: 0.348192 (epoch no 437)
# score: 0.347959 (epoch no 438)
# score: 0.347658 (epoch no 439)
# score: 0.347337 (epoch no 440)
# score: 0.348219 (epoch no 441)
# score: 0.348229 (epoch no 442)
# score: 0.348125 (epoch no 443)
# score: 0.348369 (epoch no 444)
# score: 0.348031 (epoch no 445)
# score: 0.348756 (epoch no 446)
# score: 0.348532 (epoch no 447)
# score: 0.348373 (epoch no 448)
# score: 0.347935 (epoch no 449)
# score: 0.348095 (epoch no 450)
# score: 0.348713 (epoch no 451)
# score: 0.348601 (epoch no 452)
# score: 0.348806 (epoch no 453)
# score: 0.347972 (epoch no 454)
# score: 0.347765 (epoch no 455)
# score: 0.345327 (epoch no 456)
# score: 0.341673 (epoch no 457)
# score: 0.336968 (epoch no 458)
# score: 0.330811 (epoch no 459)
# score: 0.321523 (epoch no 460)
# score: 0.317022 (epoch no 461)
# score: 0.323773 (epoch no 462)
# score: 0.338607 (epoch no 463)
# score: 0.346058 (epoch no 464)
# score: 0.346177 (epoch no 465)
# score: 0.345275 (epoch no 466)
# score: 0.347336 (epoch no 467)
# score: 0.347400 (epoch no 468)
# score: 0.347235 (epoch no 469)
# score: 0.347788 (epoch no 470)
# score: 0.348466 (epoch no 471)
# score: 0.349192 (epoch no 472)
# score: 0.349151 (epoch no 473)
# score: 0.349508 (epoch no 474)
# score: 0.349373 (epoch no 475)
# score: 0.349910 (epoch no 476)
# score: 0.349583 (epoch no 477)
# score: 0.349777 (epoch no 478)
# score: 0.349746 (epoch no 479)
# score: 0.349945 (epoch no 480)
# score: 0.349391 (epoch no 481)
# score: 0.349470 (epoch no 482)
# score: 0.348760 (epoch no 483)
# score: 0.347371 (epoch no 484)
# score: 0.347518 (epoch no 485)
# score: 0.344778 (epoch no 486)
# score: 0.342785 (epoch no 487)
# score: 0.338419 (epoch no 488)
# score: 0.336469 (epoch no 489)
# score: 0.333633 (epoch no 490)
# score: 0.329155 (epoch no 491)
# score: 0.330496 (epoch no 492)
# score: 0.327004 (epoch no 493)
# score: 0.337209 (epoch no 494)
# score: 0.344835 (epoch no 495)
# score: 0.346843 (epoch no 496)
# score: 0.348444 (epoch no 497)
# score: 0.349305 (epoch no 498)
# score: 0.348163 (epoch no 499)

# %%
pred = model.predict(X[test]).reshape(-1)
sns.distplot(pred + y_mean, color='blue')
sns.distplot(y[test] + y_mean, color='orange')

# %%
EPOCHS = 308

model = Sequential()

model.add(Dense(input_dim=100, output_dim=100, init='uniform'))
model.add(Activation('tanh'))

model.add(Dense(input_dim=100, output_dim=1, init='uniform'))
model.add(Activation('linear'))

model.compile(loss="mean_squared_error", optimizer="sgd") 

with StatusCallback(epoch_total=EPOCHS) as status:
    model.fit(X, y, nb_epoch=EPOCHS, batch_size=100000, callbacks=[status], verbose=0)

# %%
y_valid = model.predict(X_valid) + y_mean
y_test = model.predict(X_test) + y_mean

# %%
np.savetxt('submission/yolanda_valid.predict', y_valid, fmt='%0.5f')
np.savetxt('submission/yolanda_test.predict', y_test, fmt='%0.5f')
