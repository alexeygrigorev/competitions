# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import feather
import pickle

# %%
with open('topics.bin', 'rb') as f:
    all_topics, selected_topics = pickle.load(f)

# %%
df_train = feather.read_dataframe('df_train.feather')
df_val = feather.read_dataframe('df_val.feather')
df_test = feather.read_dataframe('df_test.feather')

# %%
df_all = pd.concat([df_train, df_val]).reset_index(drop=1)
del df_train, df_val

# %%
def get_y(df, topics):
    topic_idx = {t: i for (i, t) in enumerate(topics)}
    y = np.zeros((len(df), len(topics)), dtype='uint8')

    for idx, topics in enumerate(df.topics):
        for t in topics.split(','):
            if t in topic_idx:
                y[idx, topic_idx[t]] = 1
    return y

y_train = get_y(df_all, selected_topics)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import log_loss, f1_score

from sklearn.cross_validation import KFold

cv = KFold(n=len(df_all), n_folds=3, shuffle=True, random_state=1)
# Out:
# /home/agrigorev/anaconda3/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
vec = TfidfVectorizer(stop_words='english', ngram_range=(1, 3), min_df=10)

X_train = vec.fit_transform(df_all.body)
X_test = vec.transform(df_test.body)

# %%
svd = TruncatedSVD(n_components=180, random_state=1)

X_train = svd.fit_transform(X_train).astype('float32')
X_test = svd.transform(X_test).astype('float32')

# %%
scaler = StandardScaler(with_mean=True, copy=False)
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD, Adam
from keras.regularizers import l1, l2
from keras.callbacks import EarlyStopping
from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import PReLU, ELU, LeakyReLU
from keras.callbacks import EarlyStopping, Callback
# Out:
# Using Theano backend.

# %%
class WatchlistCallback(Callback):
    def __init__(self, watchlist):
        super(Callback, self).__init__()
        self.X, self.y = watchlist

    def on_epoch_end(self, epoch, logs={}):
        y_pred = self.model.predict(self.X, verbose=0)

        print("epoch no %d" % (epoch), end=', ')
        print('logloss=%.4f' % log_loss(self.y, y_pred), end=', ')

        f = f1_score(self.y, y_pred >= 0.5, average='micro')
        print('f1=%0.4f' % f)

# %%
input_dim = X_train.shape[1]
output_dim = y_train.shape[1]

# %%
def nnet():
    model = Sequential()

    model.add(Dense(input_dim=input_dim, units=350, kernel_initializer='glorot_uniform')) 
    model.add(PReLU())
    model.add(Dropout(0.2))

    model.add(BatchNormalization())

    model.add(Dense(input_dim=350, units=350, kernel_initializer='glorot_uniform')) 
    model.add(PReLU())
    model.add(Dropout(0.2)) 

    model.add(BatchNormalization())

    model.add(Dense(units=output_dim, kernel_initializer='glorot_uniform')) 
    model.add(Activation('sigmoid'))

    model.compile(loss='binary_crossentropy', optimizer=Adam(lr=0.001))

    return model

# %%
from time import time

# %%
train_preds = []
test_preds = []
models = []

epochs = 600

for i, (train_idx, val_idx) in enumerate(cv):
    t0 = time()
    print('fold %d...' % i)
    model = nnet()
    
    watchlist = WatchlistCallback(watchlist=(X_train[val_idx], y_train[val_idx]))
    model.fit(X_train[train_idx], y_train[train_idx], epochs=epochs, 
              batch_size=50000, callbacks=[watchlist], verbose=0)
    models.append(model)

    y_pred = model.predict(X_train[val_idx])
    y_pred_test = model.predict(X_test)

    train_preds.append(y_pred)
    test_preds.append(y_pred_test)

    print('fold %d, took %.3fs' % (i, time() - t0))
    print()
# Out:
# fold 0...
# epoch no 0, logloss=7.0342, f1=0.0258
# epoch no 1, logloss=6.9478, f1=0.0314
# epoch no 2, logloss=6.8749, f1=0.0351
# epoch no 3, logloss=6.8116, f1=0.0382
# epoch no 4, logloss=6.7556, f1=0.0416
# epoch no 5, logloss=6.7070, f1=0.0460
# epoch no 6, logloss=6.6673, f1=0.0522
# epoch no 7, logloss=6.6359, f1=0.0609
# epoch no 8, logloss=6.6050, f1=0.0764
# epoch no 9, logloss=6.5728, f1=0.1046
# epoch no 10, logloss=6.5374, f1=0.1570
# epoch no 11, logloss=6.5005, f1=0.2480
# epoch no 12, logloss=6.4620, f1=0.3771
# epoch no 13, logloss=6.4184, f1=0.5169
# epoch no 14, logloss=6.3655, f1=0.5915
# epoch no 15, logloss=6.3124, f1=0.5915
# epoch no 16, logloss=6.2595, f1=0.5626
# epoch no 17, logloss=6.2086, f1=0.5230
# epoch no 18, logloss=6.1654, f1=0.4815
# epoch no 19, logloss=6.1184, f1=0.4348
# epoch no 20, logloss=6.0788, f1=0.3933
# epoch no 21, logloss=6.0161, f1=0.3412
# epoch no 22, logloss=5.9864, f1=0.3127
# epoch no 23, logloss=5.9503, f1=0.2869
# epoch no 24, logloss=5.9021, f1=0.2556
# epoch no 25, logloss=5.8657, f1=0.2424
# epoch no 26, logloss=5.8134, f1=0.2237
# epoch no 27, logloss=5.7541, f1=0.2111
# epoch no 28, logloss=5.6989, f1=0.2108
# epoch no 29, logloss=5.6404, f1=0.2161
# epoch no 30, logloss=5.5627, f1=0.2177
# epoch no 31, logloss=5.4780, f1=0.2205
# epoch no 32, logloss=5.4001, f1=0.2345
# epoch no 33, logloss=5.3123, f1=0.2471
# epoch no 34, logloss=5.2206, f1=0.2625
# epoch no 35, logloss=5.1231, f1=0.2783
# epoch no 36, logloss=5.0256, f1=0.2965
# epoch no 37, logloss=4.9342, f1=0.3180
# epoch no 38, logloss=4.8430, f1=0.3380
# epoch no 39, logloss=4.7424, f1=0.3529
# epoch no 40, logloss=4.6443, f1=0.3662
# epoch no 41, logloss=4.5485, f1=0.3810
# epoch no 42, logloss=4.4558, f1=0.3930
# epoch no 43, logloss=4.3731, f1=0.4056
# epoch no 44, logloss=4.2992, f1=0.4174
# epoch no 45, logloss=4.2253, f1=0.4266
# epoch no 46, logloss=4.1485, f1=0.4332
# epoch no 47, logloss=4.0757, f1=0.4391
# epoch no 48, logloss=4.0137, f1=0.4466
# epoch no 49, logloss=3.9558, f1=0.4511
# epoch no 50, logloss=3.9027, f1=0.4585
# epoch no 51, logloss=3.8526, f1=0.4664
# epoch no 52, logloss=3.8005, f1=0.4733
# epoch no 53, logloss=3.7467, f1=0.4766
# epoch no 54, logloss=3.6957, f1=0.4806
# epoch no 55, logloss=3.6493, f1=0.4863
# epoch no 56, logloss=3.6015, f1=0.4901
# epoch no 57, logloss=3.5550, f1=0.4943
# epoch no 58, logloss=3.5127, f1=0.4988
# epoch no 59, logloss=3.4720, f1=0.5047
# epoch no 60, logloss=3.4298, f1=0.5067
# epoch no 61, logloss=3.3904, f1=0.5108
# epoch no 62, logloss=3.3527, f1=0.5163
# epoch no 63, logloss=3.3156, f1=0.5210
# epoch no 64, logloss=3.2795, f1=0.5231
# epoch no 65, logloss=3.2445, f1=0.5256
# epoch no 66, logloss=3.2105, f1=0.5291
# epoch no 67, logloss=3.1797, f1=0.5362
# epoch no 68, logloss=3.1546, f1=0.5390
# epoch no 69, logloss=3.1283, f1=0.5405
# epoch no 70, logloss=3.0990, f1=0.5426
# epoch no 71, logloss=3.0707, f1=0.5459
# epoch no 72, logloss=3.0444, f1=0.5491
# epoch no 73, logloss=3.0185, f1=0.5511
# epoch no 74, logloss=2.9910, f1=0.5544
# epoch no 75, logloss=2.9644, f1=0.5581
# epoch no 76, logloss=2.9371, f1=0.5628
# epoch no 77, logloss=2.9126, f1=0.5677
# epoch no 78, logloss=2.8933, f1=0.5704
# epoch no 79, logloss=2.8731, f1=0.5729
# epoch no 80, logloss=2.8495, f1=0.5767
# epoch no 81, logloss=2.8291, f1=0.5777
# epoch no 82, logloss=2.8107, f1=0.5795
# epoch no 83, logloss=2.7945, f1=0.5813
# epoch no 84, logloss=2.7783, f1=0.5840
# epoch no 85, logloss=2.7592, f1=0.5876
# epoch no 86, logloss=2.7418, f1=0.5905
# epoch no 87, logloss=2.7277, f1=0.5914
# epoch no 88, logloss=2.7125, f1=0.5929
# epoch no 89, logloss=2.6935, f1=0.5960
# epoch no 90, logloss=2.6747, f1=0.5999
# epoch no 91, logloss=2.6578, f1=0.6027
# epoch no 92, logloss=2.6437, f1=0.6044
# epoch no 93, logloss=2.6288, f1=0.6065
# epoch no 94, logloss=2.6134, f1=0.6093
# epoch no 95, logloss=2.6008, f1=0.6116
# epoch no 96, logloss=2.5904, f1=0.6124
# epoch no 97, logloss=2.5782, f1=0.6134
# epoch no 98, logloss=2.5657, f1=0.6152
# epoch no 99, logloss=2.5547, f1=0.6165
# epoch no 100, logloss=2.5447, f1=0.6169
# epoch no 101, logloss=2.5341, f1=0.6172
# epoch no 102, logloss=2.5228, f1=0.6181
# epoch no 103, logloss=2.5129, f1=0.6190
# epoch no 104, logloss=2.5039, f1=0.6205
# epoch no 105, logloss=2.4945, f1=0.6218
# epoch no 106, logloss=2.4842, f1=0.6234
# epoch no 107, logloss=2.4758, f1=0.6238
# epoch no 108, logloss=2.4680, f1=0.6241
# epoch no 109, logloss=2.4583, f1=0.6260
# epoch no 110, logloss=2.4493, f1=0.6274
# epoch no 111, logloss=2.4401, f1=0.6291
# epoch no 112, logloss=2.4319, f1=0.6299
# epoch no 113, logloss=2.4245, f1=0.6306
# epoch no 114, logloss=2.4186, f1=0.6308
# epoch no 115, logloss=2.4094, f1=0.6321
# epoch no 116, logloss=2.4008, f1=0.6333
# epoch no 117, logloss=2.3934, f1=0.6341
# epoch no 118, logloss=2.3872, f1=0.6351
# epoch no 119, logloss=2.3815, f1=0.6349
# epoch no 120, logloss=2.3734, f1=0.6360
# epoch no 121, logloss=2.3661, f1=0.6381
# epoch no 122, logloss=2.3608, f1=0.6387
# epoch no 123, logloss=2.3560, f1=0.6391
# epoch no 124, logloss=2.3513, f1=0.6396
# epoch no 125, logloss=2.3465, f1=0.6394
# epoch no 126, logloss=2.3401, f1=0.6403
# epoch no 127, logloss=2.3347, f1=0.6400
# epoch no 128, logloss=2.3290, f1=0.6402
# epoch no 129, logloss=2.3227, f1=0.6412
# epoch no 130, logloss=2.3152, f1=0.6428
# epoch no 131, logloss=2.3098, f1=0.6439
# epoch no 132, logloss=2.3044, f1=0.6449
# epoch no 133, logloss=2.3003, f1=0.6448
# epoch no 134, logloss=2.2967, f1=0.6439
# epoch no 135, logloss=2.2928, f1=0.6440
# epoch no 136, logloss=2.2901, f1=0.6449
# epoch no 137, logloss=2.2862, f1=0.6450
# epoch no 138, logloss=2.2813, f1=0.6453
# epoch no 139, logloss=2.2797, f1=0.6435
# epoch no 140, logloss=2.2739, f1=0.6456
# epoch no 141, logloss=2.2668, f1=0.6467
# epoch no 142, logloss=2.2615, f1=0.6452
# epoch no 143, logloss=2.2579, f1=0.6441
# epoch no 144, logloss=2.2549, f1=0.6449
# epoch no 145, logloss=2.2523, f1=0.6460
# epoch no 146, logloss=2.2481, f1=0.6468
# epoch no 147, logloss=2.2440, f1=0.6453
# epoch no 148, logloss=2.2403, f1=0.6436
# epoch no 149, logloss=2.2336, f1=0.6452
# epoch no 150, logloss=2.2300, f1=0.6470
# epoch no 151, logloss=2.2266, f1=0.6495
# epoch no 152, logloss=2.2213, f1=0.6512
# epoch no 153, logloss=2.2167, f1=0.6508
# epoch no 154, logloss=2.2136, f1=0.6483
# epoch no 155, logloss=2.2143, f1=0.6471
# epoch no 156, logloss=2.2135, f1=0.6511
# epoch no 157, logloss=2.2066, f1=0.6580
# epoch no 158, logloss=2.2004, f1=0.6581
# epoch no 159, logloss=2.1965, f1=0.6532
# epoch no 160, logloss=2.1909, f1=0.6529
# epoch no 161, logloss=2.1874, f1=0.6531
# epoch no 162, logloss=2.1895, f1=0.6490
# epoch no 163, logloss=2.1859, f1=0.6500
# epoch no 164, logloss=2.1800, f1=0.6519
# epoch no 165, logloss=2.1767, f1=0.6497
# epoch no 166, logloss=2.1760, f1=0.6471
# epoch no 167, logloss=2.1710, f1=0.6491
# epoch no 168, logloss=2.1644, f1=0.6528
# epoch no 169, logloss=2.1635, f1=0.6510
# epoch no 170, logloss=2.1657, f1=0.6500
# epoch no 171, logloss=2.1593, f1=0.6548
# epoch no 172, logloss=2.1523, f1=0.6567
# epoch no 173, logloss=2.1522, f1=0.6517
# epoch no 174, logloss=2.1493, f1=0.6540
# epoch no 175, logloss=2.1414, f1=0.6607
# epoch no 176, logloss=2.1412, f1=0.6563
# epoch no 177, logloss=2.1410, f1=0.6511
# epoch no 178, logloss=2.1347, f1=0.6542
# epoch no 179, logloss=2.1310, f1=0.6553
# epoch no 180, logloss=2.1286, f1=0.6543
# epoch no 181, logloss=2.1264, f1=0.6542
# epoch no 182, logloss=2.1224, f1=0.6559
# epoch no 183, logloss=2.1204, f1=0.6542
# epoch no 184, logloss=2.1167, f1=0.6531
# epoch no 185, logloss=2.1120, f1=0.6542
# epoch no 186, logloss=2.1107, f1=0.6571
# epoch no 187, logloss=2.1083, f1=0.6626
# epoch no 188, logloss=2.1023, f1=0.6661
# epoch no 189, logloss=2.1000, f1=0.6612
# epoch no 190, logloss=2.0972, f1=0.6587
# epoch no 191, logloss=2.0935, f1=0.6599
# epoch no 192, logloss=2.0918, f1=0.6608
# epoch no 193, logloss=2.0880, f1=0.6601
# epoch no 194, logloss=2.0847, f1=0.6601
# epoch no 195, logloss=2.0818, f1=0.6622
# epoch no 196, logloss=2.0803, f1=0.6632
# epoch no 197, logloss=2.0809, f1=0.6604
# epoch no 198, logloss=2.0757, f1=0.6613
# epoch no 199, logloss=2.0698, f1=0.6631
# epoch no 200, logloss=2.0696, f1=0.6610
# epoch no 201, logloss=2.0672, f1=0.6611
# epoch no 202, logloss=2.0625, f1=0.6651
# epoch no 203, logloss=2.0594, f1=0.6676
# epoch no 204, logloss=2.0586, f1=0.6666
# epoch no 205, logloss=2.0578, f1=0.6632
# epoch no 206, logloss=2.0562, f1=0.6609
# epoch no 207, logloss=2.0549, f1=0.6622
# epoch no 208, logloss=2.0476, f1=0.6689
# epoch no 209, logloss=2.0456, f1=0.6685
# epoch no 210, logloss=2.0478, f1=0.6636
# epoch no 211, logloss=2.0419, f1=0.6666
# epoch no 212, logloss=2.0398, f1=0.6670
# epoch no 213, logloss=2.0371, f1=0.6693
# epoch no 214, logloss=2.0328, f1=0.6744
# epoch no 215, logloss=2.0294, f1=0.6756
# epoch no 216, logloss=2.0250, f1=0.6767
# epoch no 217, logloss=2.0238, f1=0.6762
# epoch no 218, logloss=2.0226, f1=0.6744
# epoch no 219, logloss=2.0222, f1=0.6725
# epoch no 220, logloss=2.0148, f1=0.6807
# epoch no 221, logloss=2.0124, f1=0.6817
# epoch no 222, logloss=2.0156, f1=0.6738
# epoch no 223, logloss=2.0089, f1=0.6758
# epoch no 224, logloss=2.0059, f1=0.6793
# epoch no 225, logloss=2.0053, f1=0.6797
# epoch no 226, logloss=1.9995, f1=0.6829
# epoch no 227, logloss=1.9965, f1=0.6836
# epoch no 228, logloss=1.9978, f1=0.6814
# epoch no 229, logloss=1.9991, f1=0.6794
# epoch no 230, logloss=1.9932, f1=0.6828
# epoch no 231, logloss=1.9931, f1=0.6813
# epoch no 232, logloss=1.9918, f1=0.6837
# epoch no 233, logloss=1.9873, f1=0.6883
# epoch no 234, logloss=1.9847, f1=0.6869
# epoch no 235, logloss=1.9841, f1=0.6837
# epoch no 236, logloss=1.9841, f1=0.6814
# epoch no 237, logloss=1.9819, f1=0.6834
# epoch no 238, logloss=1.9776, f1=0.6868
# epoch no 239, logloss=1.9757, f1=0.6864
# epoch no 240, logloss=1.9746, f1=0.6864
# epoch no 241, logloss=1.9714, f1=0.6890
# epoch no 242, logloss=1.9718, f1=0.6885
# epoch no 243, logloss=1.9680, f1=0.6910
# epoch no 244, logloss=1.9657, f1=0.6909
# epoch no 245, logloss=1.9676, f1=0.6869
# epoch no 246, logloss=1.9627, f1=0.6897
# epoch no 247, logloss=1.9607, f1=0.6916
# epoch no 248, logloss=1.9582, f1=0.6934
# epoch no 249, logloss=1.9555, f1=0.6937
# epoch no 250, logloss=1.9581, f1=0.6900
# epoch no 251, logloss=1.9527, f1=0.6932
# epoch no 252, logloss=1.9525, f1=0.6928
# epoch no 253, logloss=1.9512, f1=0.6932
# epoch no 254, logloss=1.9474, f1=0.6955
# epoch no 255, logloss=1.9471, f1=0.6940
# epoch no 256, logloss=1.9431, f1=0.6991
# epoch no 257, logloss=1.9391, f1=0.7014
# epoch no 258, logloss=1.9401, f1=0.6978
# epoch no 259, logloss=1.9405, f1=0.6942
# epoch no 260, logloss=1.9407, f1=0.6952
# epoch no 261, logloss=1.9346, f1=0.7011
# epoch no 262, logloss=1.9322, f1=0.7016
# epoch no 263, logloss=1.9352, f1=0.6974
# epoch no 264, logloss=1.9344, f1=0.6985
# epoch no 265, logloss=1.9333, f1=0.6975
# epoch no 266, logloss=1.9324, f1=0.6958
# epoch no 267, logloss=1.9273, f1=0.6989
# epoch no 268, logloss=1.9283, f1=0.6968
# epoch no 269, logloss=1.9250, f1=0.7008
# epoch no 270, logloss=1.9213, f1=0.7042
# epoch no 271, logloss=1.9256, f1=0.6993
# epoch no 272, logloss=1.9215, f1=0.7008
# epoch no 273, logloss=1.9184, f1=0.7026
# epoch no 274, logloss=1.9198, f1=0.7012
# epoch no 275, logloss=1.9137, f1=0.7054
# epoch no 276, logloss=1.9163, f1=0.7024
# epoch no 277, logloss=1.9163, f1=0.7020
# epoch no 278, logloss=1.9122, f1=0.7046
# epoch no 279, logloss=1.9108, f1=0.7041
# epoch no 280, logloss=1.9138, f1=0.6996
# epoch no 281, logloss=1.9129, f1=0.6993
# epoch no 282, logloss=1.9088, f1=0.7022
# epoch no 283, logloss=1.9092, f1=0.7016
# epoch no 284, logloss=1.9073, f1=0.7045
# epoch no 285, logloss=1.9050, f1=0.7060
# epoch no 286, logloss=1.9039, f1=0.7049
# epoch no 287, logloss=1.9039, f1=0.7057
# epoch no 288, logloss=1.9022, f1=0.7073
# epoch no 289, logloss=1.9011, f1=0.7074
# epoch no 290, logloss=1.8982, f1=0.7093
# epoch no 291, logloss=1.8991, f1=0.7090
# epoch no 292, logloss=1.8945, f1=0.7119
# epoch no 293, logloss=1.8951, f1=0.7101
# epoch no 294, logloss=1.8992, f1=0.7047
# epoch no 295, logloss=1.8941, f1=0.7073
# epoch no 296, logloss=1.8936, f1=0.7072
# epoch no 297, logloss=1.8941, f1=0.7073
# epoch no 298, logloss=1.8907, f1=0.7111
# epoch no 299, logloss=1.8907, f1=0.7104
# epoch no 300, logloss=1.8909, f1=0.7091
# epoch no 301, logloss=1.8863, f1=0.7128
# epoch no 302, logloss=1.8877, f1=0.7110
# epoch no 303, logloss=1.8865, f1=0.7105
# epoch no 304, logloss=1.8877, f1=0.7095
# epoch no 305, logloss=1.8865, f1=0.7113
# epoch no 306, logloss=1.8824, f1=0.7142
# epoch no 307, logloss=1.8836, f1=0.7118
# epoch no 308, logloss=1.8839, f1=0.7101
# epoch no 309, logloss=1.8814, f1=0.7121
# epoch no 310, logloss=1.8808, f1=0.7105
# epoch no 311, logloss=1.8848, f1=0.7067
# epoch no 312, logloss=1.8788, f1=0.7120
# epoch no 313, logloss=1.8758, f1=0.7140
# epoch no 314, logloss=1.8834, f1=0.7062
# epoch no 315, logloss=1.8778, f1=0.7111
# epoch no 316, logloss=1.8749, f1=0.7134
# epoch no 317, logloss=1.8781, f1=0.7112
# epoch no 318, logloss=1.8718, f1=0.7170
# epoch no 319, logloss=1.8700, f1=0.7175
# epoch no 320, logloss=1.8747, f1=0.7122
# epoch no 321, logloss=1.8735, f1=0.7116
# epoch no 322, logloss=1.8725, f1=0.7123
# epoch no 323, logloss=1.8712, f1=0.7131
# epoch no 324, logloss=1.8699, f1=0.7136
# epoch no 325, logloss=1.8673, f1=0.7147
# epoch no 326, logloss=1.8657, f1=0.7147
# epoch no 327, logloss=1.8696, f1=0.7107
# epoch no 328, logloss=1.8675, f1=0.7123
# epoch no 329, logloss=1.8604, f1=0.7179
# epoch no 330, logloss=1.8619, f1=0.7191
# epoch no 331, logloss=1.8596, f1=0.7210
# epoch no 332, logloss=1.8603, f1=0.7192
# epoch no 333, logloss=1.8625, f1=0.7164
# epoch no 334, logloss=1.8625, f1=0.7144
# epoch no 335, logloss=1.8608, f1=0.7153
# epoch no 336, logloss=1.8588, f1=0.7167
# epoch no 337, logloss=1.8619, f1=0.7158
# epoch no 338, logloss=1.8540, f1=0.7206
# epoch no 339, logloss=1.8587, f1=0.7172
# epoch no 340, logloss=1.8590, f1=0.7156
# epoch no 341, logloss=1.8560, f1=0.7167
# epoch no 342, logloss=1.8544, f1=0.7185
# epoch no 343, logloss=1.8539, f1=0.7211
# epoch no 344, logloss=1.8480, f1=0.7271
# epoch no 345, logloss=1.8468, f1=0.7286
# epoch no 346, logloss=1.8515, f1=0.7242
# epoch no 347, logloss=1.8478, f1=0.7245
# epoch no 348, logloss=1.8537, f1=0.7195
# epoch no 349, logloss=1.8503, f1=0.7210
# epoch no 350, logloss=1.8477, f1=0.7231
# epoch no 351, logloss=1.8466, f1=0.7237
# epoch no 352, logloss=1.8460, f1=0.7247
# epoch no 353, logloss=1.8452, f1=0.7249
# epoch no 354, logloss=1.8471, f1=0.7219
# epoch no 355, logloss=1.8465, f1=0.7208
# epoch no 356, logloss=1.8436, f1=0.7231
# epoch no 357, logloss=1.8489, f1=0.7181
# epoch no 358, logloss=1.8462, f1=0.7197
# epoch no 359, logloss=1.8443, f1=0.7217
# epoch no 360, logloss=1.8414, f1=0.7251
# epoch no 361, logloss=1.8389, f1=0.7271
# epoch no 362, logloss=1.8375, f1=0.7286
# epoch no 363, logloss=1.8410, f1=0.7254
# epoch no 364, logloss=1.8410, f1=0.7229
# epoch no 365, logloss=1.8383, f1=0.7230
# epoch no 366, logloss=1.8484, f1=0.7159
# epoch no 367, logloss=1.8384, f1=0.7220
# epoch no 368, logloss=1.8392, f1=0.7224
# epoch no 369, logloss=1.8432, f1=0.7200
# epoch no 370, logloss=1.8346, f1=0.7256
# epoch no 371, logloss=1.8358, f1=0.7244
# epoch no 372, logloss=1.8388, f1=0.7228
# epoch no 373, logloss=1.8352, f1=0.7251
# epoch no 374, logloss=1.8337, f1=0.7259
# epoch no 375, logloss=1.8397, f1=0.7212
# epoch no 376, logloss=1.8358, f1=0.7239
# epoch no 377, logloss=1.8312, f1=0.7277
# epoch no 378, logloss=1.8332, f1=0.7256
# epoch no 379, logloss=1.8358, f1=0.7235
# epoch no 380, logloss=1.8295, f1=0.7270
# epoch no 381, logloss=1.8310, f1=0.7257
# epoch no 382, logloss=1.8329, f1=0.7248
# epoch no 383, logloss=1.8301, f1=0.7267
# epoch no 384, logloss=1.8297, f1=0.7268
# epoch no 385, logloss=1.8307, f1=0.7238
# epoch no 386, logloss=1.8350, f1=0.7209
# epoch no 387, logloss=1.8300, f1=0.7240
# epoch no 388, logloss=1.8311, f1=0.7241
# epoch no 389, logloss=1.8263, f1=0.7284
# epoch no 390, logloss=1.8234, f1=0.7320
# epoch no 391, logloss=1.8243, f1=0.7317
# epoch no 392, logloss=1.8219, f1=0.7327
# epoch no 393, logloss=1.8248, f1=0.7294
# epoch no 394, logloss=1.8271, f1=0.7254
# epoch no 395, logloss=1.8294, f1=0.7232
# epoch no 396, logloss=1.8251, f1=0.7273
# epoch no 397, logloss=1.8232, f1=0.7300
# epoch no 398, logloss=1.8235, f1=0.7295
# epoch no 399, logloss=1.8201, f1=0.7307
# epoch no 400, logloss=1.8240, f1=0.7273
# epoch no 401, logloss=1.8253, f1=0.7255
# epoch no 402, logloss=1.8243, f1=0.7253
# epoch no 403, logloss=1.8227, f1=0.7262
# epoch no 404, logloss=1.8176, f1=0.7311
# epoch no 405, logloss=1.8167, f1=0.7328
# epoch no 406, logloss=1.8178, f1=0.7320
# epoch no 407, logloss=1.8169, f1=0.7308
# epoch no 408, logloss=1.8256, f1=0.7251
# epoch no 409, logloss=1.8182, f1=0.7293
# epoch no 410, logloss=1.8166, f1=0.7314
# epoch no 411, logloss=1.8171, f1=0.7318
# epoch no 412, logloss=1.8153, f1=0.7326
# epoch no 413, logloss=1.8159, f1=0.7309
# epoch no 414, logloss=1.8191, f1=0.7283
# epoch no 415, logloss=1.8143, f1=0.7311
# epoch no 416, logloss=1.8169, f1=0.7288
# epoch no 417, logloss=1.8172, f1=0.7288
# epoch no 418, logloss=1.8130, f1=0.7321
# epoch no 419, logloss=1.8149, f1=0.7308
# epoch no 420, logloss=1.8161, f1=0.7296
# epoch no 421, logloss=1.8140, f1=0.7309
# epoch no 422, logloss=1.8120, f1=0.7325
# epoch no 423, logloss=1.8125, f1=0.7316
# epoch no 424, logloss=1.8179, f1=0.7268
# epoch no 425, logloss=1.8078, f1=0.7335
# epoch no 426, logloss=1.8141, f1=0.7298
# epoch no 427, logloss=1.8145, f1=0.7288
# epoch no 428, logloss=1.8161, f1=0.7284
# epoch no 429, logloss=1.8076, f1=0.7351
# epoch no 430, logloss=1.8056, f1=0.7372
# epoch no 431, logloss=1.8125, f1=0.7324
# epoch no 432, logloss=1.8064, f1=0.7346
# epoch no 433, logloss=1.8101, f1=0.7326
# epoch no 434, logloss=1.8056, f1=0.7349
# epoch no 435, logloss=1.8107, f1=0.7313
# epoch no 436, logloss=1.8060, f1=0.7348
# epoch no 437, logloss=1.8049, f1=0.7363
# epoch no 438, logloss=1.8081, f1=0.7336
# epoch no 439, logloss=1.8076, f1=0.7318
# epoch no 440, logloss=1.8102, f1=0.7304
# epoch no 441, logloss=1.8036, f1=0.7340
# epoch no 442, logloss=1.8122, f1=0.7308
# epoch no 443, logloss=1.7968, f1=0.7425
# epoch no 444, logloss=1.7997, f1=0.7405
# epoch no 445, logloss=1.8046, f1=0.7361
# epoch no 446, logloss=1.8035, f1=0.7361
# epoch no 447, logloss=1.8056, f1=0.7338
# epoch no 448, logloss=1.8062, f1=0.7317
# epoch no 449, logloss=1.8051, f1=0.7330
# epoch no 450, logloss=1.8039, f1=0.7348
# epoch no 451, logloss=1.8002, f1=0.7379
# epoch no 452, logloss=1.7976, f1=0.7392
# epoch no 453, logloss=1.8038, f1=0.7342
# epoch no 454, logloss=1.8024, f1=0.7340
# epoch no 455, logloss=1.8030, f1=0.7336
# epoch no 456, logloss=1.8014, f1=0.7349
# epoch no 457, logloss=1.7990, f1=0.7362
# epoch no 458, logloss=1.8031, f1=0.7331
# epoch no 459, logloss=1.7966, f1=0.7372
# epoch no 460, logloss=1.7987, f1=0.7366
# epoch no 461, logloss=1.7992, f1=0.7354
# epoch no 462, logloss=1.8011, f1=0.7340
# epoch no 463, logloss=1.7967, f1=0.7371
# epoch no 464, logloss=1.7996, f1=0.7348
# epoch no 465, logloss=1.8030, f1=0.7318
# epoch no 466, logloss=1.7974, f1=0.7347
# epoch no 467, logloss=1.8028, f1=0.7315
# epoch no 468, logloss=1.7980, f1=0.7349
# epoch no 469, logloss=1.7964, f1=0.7377
# epoch no 470, logloss=1.7928, f1=0.7405
# epoch no 471, logloss=1.7951, f1=0.7389
# epoch no 472, logloss=1.7946, f1=0.7387
# epoch no 473, logloss=1.7938, f1=0.7383
# epoch no 474, logloss=1.7991, f1=0.7346
# epoch no 475, logloss=1.7951, f1=0.7367
# epoch no 476, logloss=1.7937, f1=0.7385
# epoch no 477, logloss=1.7962, f1=0.7370
# epoch no 478, logloss=1.7924, f1=0.7390
# epoch no 479, logloss=1.7917, f1=0.7392
# epoch no 480, logloss=1.7939, f1=0.7370
# epoch no 481, logloss=1.7909, f1=0.7385
# epoch no 482, logloss=1.7954, f1=0.7358
# epoch no 483, logloss=1.7931, f1=0.7372
# epoch no 484, logloss=1.7914, f1=0.7391
# epoch no 485, logloss=1.7895, f1=0.7416
# epoch no 486, logloss=1.7897, f1=0.7419
# epoch no 487, logloss=1.7927, f1=0.7388
# epoch no 488, logloss=1.7903, f1=0.7405
# epoch no 489, logloss=1.7855, f1=0.7452
# epoch no 490, logloss=1.7879, f1=0.7431
# epoch no 491, logloss=1.7923, f1=0.7378
# epoch no 492, logloss=1.7923, f1=0.7367
# epoch no 493, logloss=1.7919, f1=0.7384
# epoch no 494, logloss=1.7925, f1=0.7374
# epoch no 495, logloss=1.7941, f1=0.7371
# epoch no 496, logloss=1.7858, f1=0.7428
# epoch no 497, logloss=1.7907, f1=0.7396
# epoch no 498, logloss=1.7950, f1=0.7353
# epoch no 499, logloss=1.7921, f1=0.7369
# epoch no 500, logloss=1.7933, f1=0.7374
# epoch no 501, logloss=1.7906, f1=0.7387
# epoch no 502, logloss=1.7904, f1=0.7391
# epoch no 503, logloss=1.7846, f1=0.7428
# epoch no 504, logloss=1.7897, f1=0.7400
# epoch no 505, logloss=1.7905, f1=0.7383
# epoch no 506, logloss=1.7892, f1=0.7392
# epoch no 507, logloss=1.7843, f1=0.7442
# epoch no 508, logloss=1.7816, f1=0.7472
# epoch no 509, logloss=1.7881, f1=0.7412
# epoch no 510, logloss=1.7851, f1=0.7415
# epoch no 511, logloss=1.7904, f1=0.7388
# epoch no 512, logloss=1.7844, f1=0.7424
# epoch no 513, logloss=1.7882, f1=0.7412
# epoch no 514, logloss=1.7829, f1=0.7445
# epoch no 515, logloss=1.7885, f1=0.7407
# epoch no 516, logloss=1.7876, f1=0.7406
# epoch no 517, logloss=1.7825, f1=0.7438
# epoch no 518, logloss=1.7842, f1=0.7424
# epoch no 519, logloss=1.7811, f1=0.7439
# epoch no 520, logloss=1.7826, f1=0.7424
# epoch no 521, logloss=1.7840, f1=0.7408
# epoch no 522, logloss=1.7867, f1=0.7385
# epoch no 523, logloss=1.7888, f1=0.7383
# epoch no 524, logloss=1.7833, f1=0.7426
# epoch no 525, logloss=1.7850, f1=0.7426
# epoch no 526, logloss=1.7804, f1=0.7454
# epoch no 527, logloss=1.7804, f1=0.7459
# epoch no 528, logloss=1.7802, f1=0.7441
# epoch no 529, logloss=1.7886, f1=0.7378
# epoch no 530, logloss=1.7811, f1=0.7428
# epoch no 531, logloss=1.7844, f1=0.7412
# epoch no 532, logloss=1.7845, f1=0.7410
# epoch no 533, logloss=1.7821, f1=0.7433
# epoch no 534, logloss=1.7812, f1=0.7450
# epoch no 535, logloss=1.7793, f1=0.7454
# epoch no 536, logloss=1.7796, f1=0.7448
# epoch no 537, logloss=1.7786, f1=0.7445
# epoch no 538, logloss=1.7834, f1=0.7415
# epoch no 539, logloss=1.7804, f1=0.7426
# epoch no 540, logloss=1.7802, f1=0.7446
# epoch no 541, logloss=1.7773, f1=0.7461
# epoch no 542, logloss=1.7817, f1=0.7435
# epoch no 543, logloss=1.7776, f1=0.7455
# epoch no 544, logloss=1.7805, f1=0.7449
# epoch no 545, logloss=1.7750, f1=0.7487
# epoch no 546, logloss=1.7820, f1=0.7445
# epoch no 547, logloss=1.7799, f1=0.7445
# epoch no 548, logloss=1.7784, f1=0.7461
# epoch no 549, logloss=1.7780, f1=0.7461
# epoch no 550, logloss=1.7815, f1=0.7435
# epoch no 551, logloss=1.7765, f1=0.7479
# epoch no 552, logloss=1.7757, f1=0.7478
# epoch no 553, logloss=1.7811, f1=0.7440
# epoch no 554, logloss=1.7737, f1=0.7492
# epoch no 555, logloss=1.7791, f1=0.7460
# epoch no 556, logloss=1.7806, f1=0.7431
# epoch no 557, logloss=1.7761, f1=0.7477
# epoch no 558, logloss=1.7745, f1=0.7494
# epoch no 559, logloss=1.7786, f1=0.7459
# epoch no 560, logloss=1.7749, f1=0.7491
# epoch no 561, logloss=1.7733, f1=0.7501
# epoch no 562, logloss=1.7803, f1=0.7450
# epoch no 563, logloss=1.7764, f1=0.7468
# epoch no 564, logloss=1.7722, f1=0.7500
# epoch no 565, logloss=1.7751, f1=0.7487
# epoch no 566, logloss=1.7731, f1=0.7507
# epoch no 567, logloss=1.7694, f1=0.7534
# epoch no 568, logloss=1.7733, f1=0.7500
# epoch no 569, logloss=1.7779, f1=0.7457
# epoch no 570, logloss=1.7712, f1=0.7505
# epoch no 571, logloss=1.7704, f1=0.7515
# epoch no 572, logloss=1.7760, f1=0.7465
# epoch no 573, logloss=1.7770, f1=0.7464
# epoch no 574, logloss=1.7674, f1=0.7533
# epoch no 575, logloss=1.7758, f1=0.7481
# epoch no 576, logloss=1.7745, f1=0.7472
# epoch no 577, logloss=1.7765, f1=0.7457
# epoch no 578, logloss=1.7739, f1=0.7460
# epoch no 579, logloss=1.7778, f1=0.7440
# epoch no 580, logloss=1.7745, f1=0.7470
# epoch no 581, logloss=1.7732, f1=0.7485
# epoch no 582, logloss=1.7742, f1=0.7481
# epoch no 583, logloss=1.7742, f1=0.7482
# epoch no 584, logloss=1.7729, f1=0.7481
# epoch no 585, logloss=1.7786, f1=0.7440
# epoch no 586, logloss=1.7734, f1=0.7485
# epoch no 587, logloss=1.7669, f1=0.7553
# epoch no 588, logloss=1.7653, f1=0.7581
# epoch no 589, logloss=1.7693, f1=0.7542
# epoch no 590, logloss=1.7718, f1=0.7503
# epoch no 591, logloss=1.7704, f1=0.7504
# epoch no 592, logloss=1.7733, f1=0.7485
# epoch no 593, logloss=1.7721, f1=0.7491
# epoch no 594, logloss=1.7742, f1=0.7473
# epoch no 595, logloss=1.7711, f1=0.7487
# epoch no 596, logloss=1.7772, f1=0.7445
# epoch no 597, logloss=1.7712, f1=0.7491
# epoch no 598, logloss=1.7741, f1=0.7477
# epoch no 599, logloss=1.7722, f1=0.7476
# fold 0, took 11223.942s
#
# fold 1...
# epoch no 0, logloss=7.0498, f1=0.0245
# epoch no 1, logloss=6.9683, f1=0.0290
# epoch no 2, logloss=6.8977, f1=0.0331
# epoch no 3, logloss=6.8344, f1=0.0368
# epoch no 4, logloss=6.7764, f1=0.0406
# epoch no 5, logloss=6.7251, f1=0.0450
# epoch no 6, logloss=6.6796, f1=0.0523
# epoch no 7, logloss=6.6368, f1=0.0672
# epoch no 8, logloss=6.5923, f1=0.0990
# epoch no 9, logloss=6.5450, f1=0.1654
# epoch no 10, logloss=6.4893, f1=0.3041
# epoch no 11, logloss=6.4244, f1=0.4977
# epoch no 12, logloss=6.3521, f1=0.6039
# epoch no 13, logloss=6.2808, f1=0.6093
# epoch no 14, logloss=6.2122, f1=0.5778
# epoch no 15, logloss=6.1572, f1=0.5382
# epoch no 16, logloss=6.1006, f1=0.4878
# epoch no 17, logloss=6.0314, f1=0.4246
# epoch no 18, logloss=5.9864, f1=0.3720
# epoch no 19, logloss=5.9656, f1=0.3386
# epoch no 20, logloss=5.9230, f1=0.2854
# epoch no 21, logloss=5.8964, f1=0.2533
# epoch no 22, logloss=5.8626, f1=0.2265
# epoch no 23, logloss=5.8230, f1=0.1984
# epoch no 24, logloss=5.7855, f1=0.1827
# epoch no 25, logloss=5.7564, f1=0.1851
# epoch no 26, logloss=5.7033, f1=0.1748
# epoch no 27, logloss=5.6372, f1=0.1631
# epoch no 28, logloss=5.5738, f1=0.1649
# epoch no 29, logloss=5.5074, f1=0.1748
# epoch no 30, logloss=5.4213, f1=0.1768
# epoch no 31, logloss=5.3322, f1=0.1882
# epoch no 32, logloss=5.2450, f1=0.2078
# epoch no 33, logloss=5.1524, f1=0.2284
# epoch no 34, logloss=5.0517, f1=0.2456
# epoch no 35, logloss=4.9432, f1=0.2594
# epoch no 36, logloss=4.8498, f1=0.2882
# epoch no 37, logloss=4.7597, f1=0.3151
# epoch no 38, logloss=4.6540, f1=0.3310
# epoch no 39, logloss=4.5590, f1=0.3513
# epoch no 40, logloss=4.4699, f1=0.3706
# epoch no 41, logloss=4.3892, f1=0.3891
# epoch no 42, logloss=4.3055, f1=0.4037
# epoch no 43, logloss=4.2238, f1=0.4154
# epoch no 44, logloss=4.1490, f1=0.4263
# epoch no 45, logloss=4.0833, f1=0.4379
# epoch no 46, logloss=4.0132, f1=0.4458
# epoch no 47, logloss=3.9475, f1=0.4528
# epoch no 48, logloss=3.8874, f1=0.4592
# epoch no 49, logloss=3.8313, f1=0.4662
# epoch no 50, logloss=3.7765, f1=0.4726
# epoch no 51, logloss=3.7215, f1=0.4779
# epoch no 52, logloss=3.6737, f1=0.4827
# epoch no 53, logloss=3.6262, f1=0.4881
# epoch no 54, logloss=3.5823, f1=0.4944
# epoch no 55, logloss=3.5362, f1=0.4984
# epoch no 56, logloss=3.4910, f1=0.5002
# epoch no 57, logloss=3.4467, f1=0.5051
# epoch no 58, logloss=3.4085, f1=0.5100
# epoch no 59, logloss=3.3701, f1=0.5141
# epoch no 60, logloss=3.3308, f1=0.5181
# epoch no 61, logloss=3.2915, f1=0.5207
# epoch no 62, logloss=3.2554, f1=0.5242
# epoch no 63, logloss=3.2227, f1=0.5291
# epoch no 64, logloss=3.1905, f1=0.5340
# epoch no 65, logloss=3.1584, f1=0.5374
# epoch no 66, logloss=3.1260, f1=0.5406
# epoch no 67, logloss=3.0944, f1=0.5439
# epoch no 68, logloss=3.0678, f1=0.5459
# epoch no 69, logloss=3.0407, f1=0.5489
# epoch no 70, logloss=3.0128, f1=0.5527
# epoch no 71, logloss=2.9868, f1=0.5563
# epoch no 72, logloss=2.9615, f1=0.5594
# epoch no 73, logloss=2.9375, f1=0.5618
# epoch no 74, logloss=2.9143, f1=0.5642
# epoch no 75, logloss=2.8921, f1=0.5669
# epoch no 76, logloss=2.8717, f1=0.5695
# epoch no 77, logloss=2.8518, f1=0.5722
# epoch no 78, logloss=2.8318, f1=0.5751
# epoch no 79, logloss=2.8123, f1=0.5772
# epoch no 80, logloss=2.7961, f1=0.5784
# epoch no 81, logloss=2.7794, f1=0.5800
# epoch no 82, logloss=2.7599, f1=0.5838
# epoch no 83, logloss=2.7386, f1=0.5881
# epoch no 84, logloss=2.7191, f1=0.5910
# epoch no 85, logloss=2.7015, f1=0.5928
# epoch no 86, logloss=2.6848, f1=0.5951
# epoch no 87, logloss=2.6705, f1=0.5964
# epoch no 88, logloss=2.6579, f1=0.5978
# epoch no 89, logloss=2.6453, f1=0.5990
# epoch no 90, logloss=2.6300, f1=0.6017
# epoch no 91, logloss=2.6162, f1=0.6034
# epoch no 92, logloss=2.6031, f1=0.6042
# epoch no 93, logloss=2.5898, f1=0.6057
# epoch no 94, logloss=2.5765, f1=0.6071
# epoch no 95, logloss=2.5634, f1=0.6090
# epoch no 96, logloss=2.5514, f1=0.6097
# epoch no 97, logloss=2.5398, f1=0.6110
# epoch no 98, logloss=2.5287, f1=0.6122
# epoch no 99, logloss=2.5204, f1=0.6125
# epoch no 100, logloss=2.5112, f1=0.6129
# epoch no 101, logloss=2.4999, f1=0.6150
# epoch no 102, logloss=2.4879, f1=0.6173
# epoch no 103, logloss=2.4779, f1=0.6169
# epoch no 104, logloss=2.4682, f1=0.6174
# epoch no 105, logloss=2.4579, f1=0.6189
# epoch no 106, logloss=2.4469, f1=0.6212
# epoch no 107, logloss=2.4394, f1=0.6219
# epoch no 108, logloss=2.4341, f1=0.6204
# epoch no 109, logloss=2.4255, f1=0.6209
# epoch no 110, logloss=2.4157, f1=0.6220
# epoch no 111, logloss=2.4074, f1=0.6230
# epoch no 112, logloss=2.4010, f1=0.6230
# epoch no 113, logloss=2.3921, f1=0.6245
# epoch no 114, logloss=2.3858, f1=0.6259
# epoch no 115, logloss=2.3809, f1=0.6260
# epoch no 116, logloss=2.3726, f1=0.6272
# epoch no 117, logloss=2.3636, f1=0.6289
# epoch no 118, logloss=2.3578, f1=0.6295
# epoch no 119, logloss=2.3517, f1=0.6303
# epoch no 120, logloss=2.3459, f1=0.6298
# epoch no 121, logloss=2.3412, f1=0.6307
# epoch no 122, logloss=2.3347, f1=0.6322
# epoch no 123, logloss=2.3295, f1=0.6312
# epoch no 124, logloss=2.3249, f1=0.6308
# epoch no 125, logloss=2.3202, f1=0.6317
# epoch no 126, logloss=2.3136, f1=0.6331
# epoch no 127, logloss=2.3081, f1=0.6325
# epoch no 128, logloss=2.3014, f1=0.6327
# epoch no 129, logloss=2.2983, f1=0.6337
# epoch no 130, logloss=2.2929, f1=0.6350
# epoch no 131, logloss=2.2865, f1=0.6363
# epoch no 132, logloss=2.2813, f1=0.6359
# epoch no 133, logloss=2.2759, f1=0.6353
# epoch no 134, logloss=2.2730, f1=0.6347
# epoch no 135, logloss=2.2697, f1=0.6349
# epoch no 136, logloss=2.2644, f1=0.6358
# epoch no 137, logloss=2.2587, f1=0.6377
# epoch no 138, logloss=2.2562, f1=0.6375
# epoch no 139, logloss=2.2539, f1=0.6359
# epoch no 140, logloss=2.2479, f1=0.6360
# epoch no 141, logloss=2.2414, f1=0.6366
# epoch no 142, logloss=2.2378, f1=0.6369
# epoch no 143, logloss=2.2387, f1=0.6351
# epoch no 144, logloss=2.2323, f1=0.6373
# epoch no 145, logloss=2.2259, f1=0.6394
# epoch no 146, logloss=2.2217, f1=0.6401
# epoch no 147, logloss=2.2210, f1=0.6389
# epoch no 148, logloss=2.2170, f1=0.6393
# epoch no 149, logloss=2.2124, f1=0.6385
# epoch no 150, logloss=2.2128, f1=0.6367
# epoch no 151, logloss=2.2083, f1=0.6385
# epoch no 152, logloss=2.2032, f1=0.6392
# epoch no 153, logloss=2.2023, f1=0.6388
# epoch no 154, logloss=2.1986, f1=0.6396
# epoch no 155, logloss=2.1935, f1=0.6411
# epoch no 156, logloss=2.1903, f1=0.6414
# epoch no 157, logloss=2.1868, f1=0.6415
# epoch no 158, logloss=2.1862, f1=0.6393
# epoch no 159, logloss=2.1823, f1=0.6390
# epoch no 160, logloss=2.1783, f1=0.6394
# epoch no 161, logloss=2.1753, f1=0.6387
# epoch no 162, logloss=2.1738, f1=0.6377
# epoch no 163, logloss=2.1720, f1=0.6391
# epoch no 164, logloss=2.1660, f1=0.6420
# epoch no 165, logloss=2.1626, f1=0.6420
# epoch no 166, logloss=2.1601, f1=0.6402
# epoch no 167, logloss=2.1573, f1=0.6389
# epoch no 168, logloss=2.1544, f1=0.6388
# epoch no 169, logloss=2.1517, f1=0.6397
# epoch no 170, logloss=2.1518, f1=0.6394
# epoch no 171, logloss=2.1451, f1=0.6427
# epoch no 172, logloss=2.1410, f1=0.6429
# epoch no 173, logloss=2.1410, f1=0.6415
# epoch no 174, logloss=2.1360, f1=0.6428
# epoch no 175, logloss=2.1327, f1=0.6428
# epoch no 176, logloss=2.1363, f1=0.6388
# epoch no 177, logloss=2.1298, f1=0.6419
# epoch no 178, logloss=2.1232, f1=0.6440
# epoch no 179, logloss=2.1268, f1=0.6422
# epoch no 180, logloss=2.1227, f1=0.6459
# epoch no 181, logloss=2.1131, f1=0.6511
# epoch no 182, logloss=2.1137, f1=0.6476
# epoch no 183, logloss=2.1155, f1=0.6437
# epoch no 184, logloss=2.1100, f1=0.6456
# epoch no 185, logloss=2.1053, f1=0.6472
# epoch no 186, logloss=2.1070, f1=0.6461
# epoch no 187, logloss=2.1015, f1=0.6499
# epoch no 188, logloss=2.0944, f1=0.6528
# epoch no 189, logloss=2.0945, f1=0.6490
# epoch no 190, logloss=2.0938, f1=0.6468
# epoch no 191, logloss=2.0882, f1=0.6508
# epoch no 192, logloss=2.0858, f1=0.6521
# epoch no 193, logloss=2.0863, f1=0.6486
# epoch no 194, logloss=2.0849, f1=0.6456
# epoch no 195, logloss=2.0800, f1=0.6476
# epoch no 196, logloss=2.0772, f1=0.6503
# epoch no 197, logloss=2.0724, f1=0.6529
# epoch no 198, logloss=2.0713, f1=0.6527
# epoch no 199, logloss=2.0680, f1=0.6538
# epoch no 200, logloss=2.0665, f1=0.6515
# epoch no 201, logloss=2.0665, f1=0.6502
# epoch no 202, logloss=2.0654, f1=0.6532
# epoch no 203, logloss=2.0556, f1=0.6625
# epoch no 204, logloss=2.0537, f1=0.6621
# epoch no 205, logloss=2.0599, f1=0.6568
# epoch no 206, logloss=2.0564, f1=0.6610
# epoch no 207, logloss=2.0467, f1=0.6688
# epoch no 208, logloss=2.0469, f1=0.6656
# epoch no 209, logloss=2.0444, f1=0.6650
# epoch no 210, logloss=2.0396, f1=0.6657
# epoch no 211, logloss=2.0399, f1=0.6652
# epoch no 212, logloss=2.0336, f1=0.6683
# epoch no 213, logloss=2.0296, f1=0.6691
# epoch no 214, logloss=2.0315, f1=0.6660
# epoch no 215, logloss=2.0256, f1=0.6674
# epoch no 216, logloss=2.0223, f1=0.6659
# epoch no 217, logloss=2.0233, f1=0.6632
# epoch no 218, logloss=2.0205, f1=0.6647
# epoch no 219, logloss=2.0182, f1=0.6656
# epoch no 220, logloss=2.0167, f1=0.6636
# epoch no 221, logloss=2.0147, f1=0.6632
# epoch no 222, logloss=2.0149, f1=0.6632
# epoch no 223, logloss=2.0087, f1=0.6717
# epoch no 224, logloss=2.0026, f1=0.6787
# epoch no 225, logloss=2.0036, f1=0.6765
# epoch no 226, logloss=1.9998, f1=0.6766
# epoch no 227, logloss=1.9984, f1=0.6742
# epoch no 228, logloss=2.0008, f1=0.6706
# epoch no 229, logloss=1.9944, f1=0.6748
# epoch no 230, logloss=1.9926, f1=0.6750
# epoch no 231, logloss=1.9948, f1=0.6731
# epoch no 232, logloss=1.9899, f1=0.6736
# epoch no 233, logloss=1.9866, f1=0.6731
# epoch no 234, logloss=1.9872, f1=0.6706
# epoch no 235, logloss=1.9883, f1=0.6697
# epoch no 236, logloss=1.9849, f1=0.6777
# epoch no 237, logloss=1.9793, f1=0.6875
# epoch no 238, logloss=1.9775, f1=0.6892
# epoch no 239, logloss=1.9738, f1=0.6888
# epoch no 240, logloss=1.9714, f1=0.6863
# epoch no 241, logloss=1.9763, f1=0.6802
# epoch no 242, logloss=1.9697, f1=0.6813
# epoch no 243, logloss=1.9680, f1=0.6811
# epoch no 244, logloss=1.9708, f1=0.6783
# epoch no 245, logloss=1.9664, f1=0.6793
# epoch no 246, logloss=1.9620, f1=0.6811
# epoch no 247, logloss=1.9682, f1=0.6765
# epoch no 248, logloss=1.9622, f1=0.6795
# epoch no 249, logloss=1.9551, f1=0.6836
# epoch no 250, logloss=1.9592, f1=0.6797
# epoch no 251, logloss=1.9588, f1=0.6790
# epoch no 252, logloss=1.9538, f1=0.6820
# epoch no 253, logloss=1.9533, f1=0.6813
# epoch no 254, logloss=1.9534, f1=0.6802
# epoch no 255, logloss=1.9513, f1=0.6813
# epoch no 256, logloss=1.9485, f1=0.6822
# epoch no 257, logloss=1.9466, f1=0.6824
# epoch no 258, logloss=1.9468, f1=0.6812
# epoch no 259, logloss=1.9461, f1=0.6821
# epoch no 260, logloss=1.9420, f1=0.6850
# epoch no 261, logloss=1.9407, f1=0.6860
# epoch no 262, logloss=1.9371, f1=0.6885
# epoch no 263, logloss=1.9360, f1=0.6874
# epoch no 264, logloss=1.9378, f1=0.6858
# epoch no 265, logloss=1.9327, f1=0.6878
# epoch no 266, logloss=1.9336, f1=0.6863
# epoch no 267, logloss=1.9325, f1=0.6863
# epoch no 268, logloss=1.9304, f1=0.6880
# epoch no 269, logloss=1.9298, f1=0.6874
# epoch no 270, logloss=1.9281, f1=0.6880
# epoch no 271, logloss=1.9250, f1=0.6892
# epoch no 272, logloss=1.9259, f1=0.6872
# epoch no 273, logloss=1.9256, f1=0.6872
# epoch no 274, logloss=1.9213, f1=0.6900
# epoch no 275, logloss=1.9213, f1=0.6910
# epoch no 276, logloss=1.9202, f1=0.6907
# epoch no 277, logloss=1.9166, f1=0.6921
# epoch no 278, logloss=1.9156, f1=0.6922
# epoch no 279, logloss=1.9152, f1=0.6916
# epoch no 280, logloss=1.9145, f1=0.6918
# epoch no 281, logloss=1.9084, f1=0.6952
# epoch no 282, logloss=1.9117, f1=0.6932
# epoch no 283, logloss=1.9112, f1=0.6932
# epoch no 284, logloss=1.9083, f1=0.6932
# epoch no 285, logloss=1.9087, f1=0.6933
# epoch no 286, logloss=1.9037, f1=0.6969
# epoch no 287, logloss=1.9071, f1=0.6950
# epoch no 288, logloss=1.9026, f1=0.6977
# epoch no 289, logloss=1.9030, f1=0.6964
# epoch no 290, logloss=1.8984, f1=0.7008
# epoch no 291, logloss=1.8908, f1=0.7114
# epoch no 292, logloss=1.8954, f1=0.7085
# epoch no 293, logloss=1.8933, f1=0.7073
# epoch no 294, logloss=1.8954, f1=0.7017
# epoch no 295, logloss=1.9021, f1=0.6954
# epoch no 296, logloss=1.8973, f1=0.6964
# epoch no 297, logloss=1.8993, f1=0.6961
# epoch no 298, logloss=1.8953, f1=0.6998
# epoch no 299, logloss=1.8927, f1=0.7014
# epoch no 300, logloss=1.8890, f1=0.7035
# epoch no 301, logloss=1.8880, f1=0.7043
# epoch no 302, logloss=1.8916, f1=0.7004
# epoch no 303, logloss=1.8900, f1=0.7001
# epoch no 304, logloss=1.8893, f1=0.6996
# epoch no 305, logloss=1.8890, f1=0.6981
# epoch no 306, logloss=1.8889, f1=0.6986
# epoch no 307, logloss=1.8851, f1=0.7003
# epoch no 308, logloss=1.8898, f1=0.6960
# epoch no 309, logloss=1.8875, f1=0.6960
# epoch no 310, logloss=1.8833, f1=0.7000
# epoch no 311, logloss=1.8887, f1=0.6978
# epoch no 312, logloss=1.8798, f1=0.7029
# epoch no 313, logloss=1.8779, f1=0.7037
# epoch no 314, logloss=1.8873, f1=0.6976
# epoch no 315, logloss=1.8786, f1=0.7024
# epoch no 316, logloss=1.8850, f1=0.6990
# epoch no 317, logloss=1.8796, f1=0.7032
# epoch no 318, logloss=1.8720, f1=0.7066
# epoch no 319, logloss=1.8836, f1=0.6994
# epoch no 320, logloss=1.8771, f1=0.7024
# epoch no 321, logloss=1.8721, f1=0.7049
# epoch no 322, logloss=1.8776, f1=0.7029
# epoch no 323, logloss=1.8703, f1=0.7059
# epoch no 324, logloss=1.8692, f1=0.7072
# epoch no 325, logloss=1.8674, f1=0.7085
# epoch no 326, logloss=1.8700, f1=0.7048
# epoch no 327, logloss=1.8753, f1=0.7007
# epoch no 328, logloss=1.8684, f1=0.7051
# epoch no 329, logloss=1.8685, f1=0.7056
# epoch no 330, logloss=1.8683, f1=0.7051
# epoch no 331, logloss=1.8661, f1=0.7058
# epoch no 332, logloss=1.8662, f1=0.7049
# epoch no 333, logloss=1.8679, f1=0.7037
# epoch no 334, logloss=1.8632, f1=0.7066
# epoch no 335, logloss=1.8668, f1=0.7043
# epoch no 336, logloss=1.8662, f1=0.7055
# epoch no 337, logloss=1.8590, f1=0.7101
# epoch no 338, logloss=1.8631, f1=0.7072
# epoch no 339, logloss=1.8613, f1=0.7076
# epoch no 340, logloss=1.8589, f1=0.7088
# epoch no 341, logloss=1.8624, f1=0.7067
# epoch no 342, logloss=1.8593, f1=0.7071
# epoch no 343, logloss=1.8554, f1=0.7096
# epoch no 344, logloss=1.8549, f1=0.7112
# epoch no 345, logloss=1.8572, f1=0.7086
# epoch no 346, logloss=1.8564, f1=0.7081
# epoch no 347, logloss=1.8568, f1=0.7073
# epoch no 348, logloss=1.8542, f1=0.7095
# epoch no 349, logloss=1.8538, f1=0.7100
# epoch no 350, logloss=1.8524, f1=0.7105
# epoch no 351, logloss=1.8523, f1=0.7099
# epoch no 352, logloss=1.8538, f1=0.7082
# epoch no 353, logloss=1.8511, f1=0.7102
# epoch no 354, logloss=1.8497, f1=0.7133
# epoch no 355, logloss=1.8473, f1=0.7135
# epoch no 356, logloss=1.8519, f1=0.7088
# epoch no 357, logloss=1.8471, f1=0.7123
# epoch no 358, logloss=1.8450, f1=0.7138
# epoch no 359, logloss=1.8505, f1=0.7113
# epoch no 360, logloss=1.8434, f1=0.7153
# epoch no 361, logloss=1.8470, f1=0.7145
# epoch no 362, logloss=1.8439, f1=0.7155
# epoch no 363, logloss=1.8431, f1=0.7148
# epoch no 364, logloss=1.8419, f1=0.7165
# epoch no 365, logloss=1.8406, f1=0.7174
# epoch no 366, logloss=1.8433, f1=0.7147
# epoch no 367, logloss=1.8409, f1=0.7151
# epoch no 368, logloss=1.8469, f1=0.7118
# epoch no 369, logloss=1.8377, f1=0.7186
# epoch no 370, logloss=1.8355, f1=0.7200
# epoch no 371, logloss=1.8414, f1=0.7174
# epoch no 372, logloss=1.8318, f1=0.7219
# epoch no 373, logloss=1.8425, f1=0.7161
# epoch no 374, logloss=1.8362, f1=0.7192
# epoch no 375, logloss=1.8327, f1=0.7210
# epoch no 376, logloss=1.8401, f1=0.7179
# epoch no 377, logloss=1.8297, f1=0.7228
# epoch no 378, logloss=1.8342, f1=0.7204
# epoch no 379, logloss=1.8353, f1=0.7176
# epoch no 380, logloss=1.8352, f1=0.7168
# epoch no 381, logloss=1.8355, f1=0.7173
# epoch no 382, logloss=1.8337, f1=0.7164
# epoch no 383, logloss=1.8399, f1=0.7129
# epoch no 384, logloss=1.8315, f1=0.7179
# epoch no 385, logloss=1.8285, f1=0.7211
# epoch no 386, logloss=1.8329, f1=0.7179
# epoch no 387, logloss=1.8314, f1=0.7174
# epoch no 388, logloss=1.8275, f1=0.7205
# epoch no 389, logloss=1.8310, f1=0.7187
# epoch no 390, logloss=1.8330, f1=0.7174
# epoch no 391, logloss=1.8243, f1=0.7221
# epoch no 392, logloss=1.8347, f1=0.7174
# epoch no 393, logloss=1.8223, f1=0.7258
# epoch no 394, logloss=1.8239, f1=0.7254
# epoch no 395, logloss=1.8288, f1=0.7217
# epoch no 396, logloss=1.8224, f1=0.7234
# epoch no 397, logloss=1.8267, f1=0.7213
# epoch no 398, logloss=1.8222, f1=0.7242
# epoch no 399, logloss=1.8248, f1=0.7229
# epoch no 400, logloss=1.8251, f1=0.7214
# epoch no 401, logloss=1.8224, f1=0.7226
# epoch no 402, logloss=1.8219, f1=0.7236
# epoch no 403, logloss=1.8204, f1=0.7229
# epoch no 404, logloss=1.8258, f1=0.7192
# epoch no 405, logloss=1.8177, f1=0.7251
# epoch no 406, logloss=1.8179, f1=0.7255
# epoch no 407, logloss=1.8197, f1=0.7241
# epoch no 408, logloss=1.8174, f1=0.7249
# epoch no 409, logloss=1.8207, f1=0.7233
# epoch no 410, logloss=1.8197, f1=0.7216
# epoch no 411, logloss=1.8225, f1=0.7188
# epoch no 412, logloss=1.8204, f1=0.7202
# epoch no 413, logloss=1.8148, f1=0.7252
# epoch no 414, logloss=1.8141, f1=0.7279
# epoch no 415, logloss=1.8140, f1=0.7256
# epoch no 416, logloss=1.8208, f1=0.7206
# epoch no 417, logloss=1.8150, f1=0.7239
# epoch no 418, logloss=1.8162, f1=0.7225
# epoch no 419, logloss=1.8217, f1=0.7199
# epoch no 420, logloss=1.8125, f1=0.7259
# epoch no 421, logloss=1.8126, f1=0.7277
# epoch no 422, logloss=1.8090, f1=0.7295
# epoch no 423, logloss=1.8086, f1=0.7296
# epoch no 424, logloss=1.8086, f1=0.7288
# epoch no 425, logloss=1.8135, f1=0.7246
# epoch no 426, logloss=1.8173, f1=0.7216
# epoch no 427, logloss=1.8078, f1=0.7269
# epoch no 428, logloss=1.8174, f1=0.7230
# epoch no 429, logloss=1.8062, f1=0.7325
# epoch no 430, logloss=1.7983, f1=0.7412
# epoch no 431, logloss=1.8063, f1=0.7366
# epoch no 432, logloss=1.8074, f1=0.7313
# epoch no 433, logloss=1.8138, f1=0.7269
# epoch no 434, logloss=1.8083, f1=0.7290
# epoch no 435, logloss=1.8167, f1=0.7241
# epoch no 436, logloss=1.8060, f1=0.7302
# epoch no 437, logloss=1.7997, f1=0.7354
# epoch no 438, logloss=1.8048, f1=0.7322
# epoch no 439, logloss=1.8060, f1=0.7291
# epoch no 440, logloss=1.8118, f1=0.7262
# epoch no 441, logloss=1.8028, f1=0.7303
# epoch no 442, logloss=1.8145, f1=0.7236
# epoch no 443, logloss=1.8039, f1=0.7295
# epoch no 444, logloss=1.8057, f1=0.7296
# epoch no 445, logloss=1.8089, f1=0.7278
# epoch no 446, logloss=1.8027, f1=0.7287
# epoch no 447, logloss=1.8100, f1=0.7248
# epoch no 448, logloss=1.8026, f1=0.7288
# epoch no 449, logloss=1.8042, f1=0.7283
# epoch no 450, logloss=1.8055, f1=0.7285
# epoch no 451, logloss=1.7977, f1=0.7329
# epoch no 452, logloss=1.8098, f1=0.7272
# epoch no 453, logloss=1.8022, f1=0.7290
# epoch no 454, logloss=1.8098, f1=0.7259
# epoch no 455, logloss=1.8025, f1=0.7311
# epoch no 456, logloss=1.7964, f1=0.7353
# epoch no 457, logloss=1.8050, f1=0.7296
# epoch no 458, logloss=1.7988, f1=0.7317
# epoch no 459, logloss=1.8005, f1=0.7322
# epoch no 460, logloss=1.7991, f1=0.7318
# epoch no 461, logloss=1.8038, f1=0.7279
# epoch no 462, logloss=1.7973, f1=0.7317
# epoch no 463, logloss=1.7957, f1=0.7336
# epoch no 464, logloss=1.7964, f1=0.7330
# epoch no 465, logloss=1.7962, f1=0.7329
# epoch no 466, logloss=1.7980, f1=0.7305
# epoch no 467, logloss=1.8001, f1=0.7279
# epoch no 468, logloss=1.7997, f1=0.7289
# epoch no 469, logloss=1.7991, f1=0.7282
# epoch no 470, logloss=1.8049, f1=0.7251
# epoch no 471, logloss=1.7962, f1=0.7315
# epoch no 472, logloss=1.7951, f1=0.7329
# epoch no 473, logloss=1.7999, f1=0.7300
# epoch no 474, logloss=1.7951, f1=0.7324
# epoch no 475, logloss=1.7948, f1=0.7327
# epoch no 476, logloss=1.7970, f1=0.7319
# epoch no 477, logloss=1.7931, f1=0.7340
# epoch no 478, logloss=1.7982, f1=0.7307
# epoch no 479, logloss=1.7948, f1=0.7335
# epoch no 480, logloss=1.7911, f1=0.7372
# epoch no 481, logloss=1.7973, f1=0.7336
# epoch no 482, logloss=1.7948, f1=0.7326
# epoch no 483, logloss=1.7968, f1=0.7315
# epoch no 484, logloss=1.7920, f1=0.7354
# epoch no 485, logloss=1.7931, f1=0.7357
# epoch no 486, logloss=1.7909, f1=0.7357
# epoch no 487, logloss=1.7906, f1=0.7352
# epoch no 488, logloss=1.7903, f1=0.7348
# epoch no 489, logloss=1.7947, f1=0.7318
# epoch no 490, logloss=1.7920, f1=0.7355
# epoch no 491, logloss=1.7861, f1=0.7400
# epoch no 492, logloss=1.7885, f1=0.7377
# epoch no 493, logloss=1.7915, f1=0.7340
# epoch no 494, logloss=1.7929, f1=0.7335
# epoch no 495, logloss=1.7879, f1=0.7366
# epoch no 496, logloss=1.7910, f1=0.7344
# epoch no 497, logloss=1.7878, f1=0.7370
# epoch no 498, logloss=1.7851, f1=0.7396
# epoch no 499, logloss=1.7873, f1=0.7368
# epoch no 500, logloss=1.7898, f1=0.7347
# epoch no 501, logloss=1.7886, f1=0.7355
# epoch no 502, logloss=1.7926, f1=0.7330
# epoch no 503, logloss=1.7878, f1=0.7350
# epoch no 504, logloss=1.7880, f1=0.7358
# epoch no 505, logloss=1.7867, f1=0.7376
# epoch no 506, logloss=1.7855, f1=0.7385
# epoch no 507, logloss=1.7896, f1=0.7348
# epoch no 508, logloss=1.7890, f1=0.7345
# epoch no 509, logloss=1.7855, f1=0.7377
# epoch no 510, logloss=1.7843, f1=0.7387
# epoch no 511, logloss=1.7866, f1=0.7369
# epoch no 512, logloss=1.7868, f1=0.7360
# epoch no 513, logloss=1.7857, f1=0.7366
# epoch no 514, logloss=1.7866, f1=0.7356
# epoch no 515, logloss=1.7879, f1=0.7354
# epoch no 516, logloss=1.7826, f1=0.7388
# epoch no 517, logloss=1.7832, f1=0.7373
# epoch no 518, logloss=1.7906, f1=0.7320
# epoch no 519, logloss=1.7826, f1=0.7372
# epoch no 520, logloss=1.7854, f1=0.7353
# epoch no 521, logloss=1.7837, f1=0.7373
# epoch no 522, logloss=1.7806, f1=0.7400
# epoch no 523, logloss=1.7813, f1=0.7391
# epoch no 524, logloss=1.7864, f1=0.7357
# epoch no 525, logloss=1.7793, f1=0.7410
# epoch no 526, logloss=1.7799, f1=0.7423
# epoch no 527, logloss=1.7773, f1=0.7430
# epoch no 528, logloss=1.7806, f1=0.7416
# epoch no 529, logloss=1.7783, f1=0.7427
# epoch no 530, logloss=1.7823, f1=0.7385
# epoch no 531, logloss=1.7790, f1=0.7400
# epoch no 532, logloss=1.7829, f1=0.7375
# epoch no 533, logloss=1.7832, f1=0.7378
# epoch no 534, logloss=1.7810, f1=0.7387
# epoch no 535, logloss=1.7880, f1=0.7331
# epoch no 536, logloss=1.7800, f1=0.7379
# epoch no 537, logloss=1.7827, f1=0.7387
# epoch no 538, logloss=1.7824, f1=0.7382
# epoch no 539, logloss=1.7823, f1=0.7373
# epoch no 540, logloss=1.7757, f1=0.7433
# epoch no 541, logloss=1.7764, f1=0.7437
# epoch no 542, logloss=1.7827, f1=0.7389
# epoch no 543, logloss=1.7798, f1=0.7390
# epoch no 544, logloss=1.7816, f1=0.7382
# epoch no 545, logloss=1.7852, f1=0.7360
# epoch no 546, logloss=1.7796, f1=0.7384
# epoch no 547, logloss=1.7793, f1=0.7387
# epoch no 548, logloss=1.7796, f1=0.7402
# epoch no 549, logloss=1.7759, f1=0.7428
# epoch no 550, logloss=1.7794, f1=0.7392
# epoch no 551, logloss=1.7815, f1=0.7387
# epoch no 552, logloss=1.7787, f1=0.7419
# epoch no 553, logloss=1.7713, f1=0.7481
# epoch no 554, logloss=1.7651, f1=0.7550
# epoch no 555, logloss=1.7679, f1=0.7536
# epoch no 556, logloss=1.7751, f1=0.7466
# epoch no 557, logloss=1.7772, f1=0.7429
# epoch no 558, logloss=1.7792, f1=0.7411
# epoch no 559, logloss=1.7749, f1=0.7432
# epoch no 560, logloss=1.7775, f1=0.7410
# epoch no 561, logloss=1.7772, f1=0.7408
# epoch no 562, logloss=1.7739, f1=0.7439
# epoch no 563, logloss=1.7781, f1=0.7414
# epoch no 564, logloss=1.7794, f1=0.7403
# epoch no 565, logloss=1.7779, f1=0.7401
# epoch no 566, logloss=1.7823, f1=0.7366
# epoch no 567, logloss=1.7775, f1=0.7393
# epoch no 568, logloss=1.7770, f1=0.7410
# epoch no 569, logloss=1.7757, f1=0.7422
# epoch no 570, logloss=1.7753, f1=0.7421
# epoch no 571, logloss=1.7814, f1=0.7386
# epoch no 572, logloss=1.7759, f1=0.7423
# epoch no 573, logloss=1.7779, f1=0.7409
# epoch no 574, logloss=1.7767, f1=0.7416
# epoch no 575, logloss=1.7745, f1=0.7433
# epoch no 576, logloss=1.7685, f1=0.7485
# epoch no 577, logloss=1.7703, f1=0.7480
# epoch no 578, logloss=1.7720, f1=0.7468
# epoch no 579, logloss=1.7714, f1=0.7453
# epoch no 580, logloss=1.7754, f1=0.7421
# epoch no 581, logloss=1.7740, f1=0.7430
# epoch no 582, logloss=1.7714, f1=0.7454
# epoch no 583, logloss=1.7709, f1=0.7449
# epoch no 584, logloss=1.7692, f1=0.7454
# epoch no 585, logloss=1.7680, f1=0.7473
# epoch no 586, logloss=1.7699, f1=0.7458
# epoch no 587, logloss=1.7750, f1=0.7414
# epoch no 588, logloss=1.7782, f1=0.7393
# epoch no 589, logloss=1.7722, f1=0.7429
# epoch no 590, logloss=1.7696, f1=0.7464
# epoch no 591, logloss=1.7612, f1=0.7534
# epoch no 592, logloss=1.7659, f1=0.7498
# epoch no 593, logloss=1.7691, f1=0.7458
# epoch no 594, logloss=1.7739, f1=0.7424
# epoch no 595, logloss=1.7705, f1=0.7449
# epoch no 596, logloss=1.7736, f1=0.7432
# epoch no 597, logloss=1.7713, f1=0.7443
# epoch no 598, logloss=1.7675, f1=0.7470
# epoch no 599, logloss=1.7693, f1=0.7464
# fold 1, took 8648.258s
#
# fold 2...
# epoch no 0, logloss=7.0694, f1=0.0256
# epoch no 1, logloss=6.9840, f1=0.0307
# epoch no 2, logloss=6.9105, f1=0.0343
# ...
# epoch no 201, logloss=2.0849, f1=0.6605
# epoch no 202, logloss=2.0826, f1=0.6606
# epoch no 203, logloss=2.0787, f1=0.6632
# epoch no 204, logloss=2.0764, f1=0.6635
# epoch no 205, logloss=2.0748, f1=0.6610
# epoch no 206, logloss=2.0706, f1=0.6604
# epoch no 207, logloss=2.0684, f1=0.6604
# epoch no 208, logloss=2.0702, f1=0.6606
# epoch no 209, logloss=2.0662, f1=0.6653
# epoch no 210, logloss=2.0607, f1=0.6693
# epoch no 211, logloss=2.0592, f1=0.6668
# epoch no 212, logloss=2.0607, f1=0.6629
# epoch no 213, logloss=2.0550, f1=0.6646
# epoch no 214, logloss=2.0508, f1=0.6678
# epoch no 215, logloss=2.0530, f1=0.6677
# epoch no 216, logloss=2.0510, f1=0.6689
# epoch no 217, logloss=2.0458, f1=0.6693
# epoch no 218, logloss=2.0432, f1=0.6670
# epoch no 219, logloss=2.0430, f1=0.6649
# epoch no 220, logloss=2.0423, f1=0.6638
# epoch no 221, logloss=2.0389, f1=0.6658
# epoch no 222, logloss=2.0363, f1=0.6685
# epoch no 223, logloss=2.0316, f1=0.6712
# epoch no 224, logloss=2.0286, f1=0.6711
# epoch no 225, logloss=2.0284, f1=0.6707
# epoch no 226, logloss=2.0262, f1=0.6717
# epoch no 227, logloss=2.0253, f1=0.6720
# epoch no 228, logloss=2.0249, f1=0.6719
# epoch no 229, logloss=2.0199, f1=0.6732
# epoch no 230, logloss=2.0166, f1=0.6734
# epoch no 231, logloss=2.0168, f1=0.6727
# epoch no 232, logloss=2.0126, f1=0.6755
# epoch no 233, logloss=2.0095, f1=0.6770
# epoch no 234, logloss=2.0091, f1=0.6754
# epoch no 235, logloss=2.0056, f1=0.6749
# epoch no 236, logloss=2.0048, f1=0.6743
# epoch no 237, logloss=2.0029, f1=0.6754
# epoch no 238, logloss=2.0001, f1=0.6767
# epoch no 239, logloss=1.9988, f1=0.6751
# epoch no 240, logloss=1.9998, f1=0.6727
# epoch no 241, logloss=1.9977, f1=0.6740
# epoch no 242, logloss=1.9917, f1=0.6775
# epoch no 243, logloss=1.9910, f1=0.6773
# epoch no 244, logloss=1.9937, f1=0.6751
# epoch no 245, logloss=1.9873, f1=0.6792
# epoch no 246, logloss=1.9849, f1=0.6816
# epoch no 247, logloss=1.9882, f1=0.6799
# epoch no 248, logloss=1.9831, f1=0.6828
# epoch no 249, logloss=1.9800, f1=0.6826
# epoch no 250, logloss=1.9854, f1=0.6792
# epoch no 251, logloss=1.9819, f1=0.6833
# epoch no 252, logloss=1.9747, f1=0.6895
# epoch no 253, logloss=1.9739, f1=0.6878
# epoch no 254, logloss=1.9722, f1=0.6844
# epoch no 255, logloss=1.9697, f1=0.6829
# epoch no 256, logloss=1.9709, f1=0.6826
# epoch no 257, logloss=1.9671, f1=0.6841
# epoch no 258, logloss=1.9663, f1=0.6830
# epoch no 259, logloss=1.9655, f1=0.6825
# epoch no 260, logloss=1.9614, f1=0.6848
# epoch no 261, logloss=1.9619, f1=0.6848
# epoch no 262, logloss=1.9601, f1=0.6857
# epoch no 263, logloss=1.9560, f1=0.6874
# epoch no 264, logloss=1.9558, f1=0.6869
# epoch no 265, logloss=1.9539, f1=0.6875
# epoch no 266, logloss=1.9512, f1=0.6883
# epoch no 267, logloss=1.9484, f1=0.6891
# epoch no 268, logloss=1.9487, f1=0.6871
# epoch no 269, logloss=1.9500, f1=0.6880
# epoch no 270, logloss=1.9433, f1=0.6939
# epoch no 271, logloss=1.9419, f1=0.6935
# epoch no 272, logloss=1.9409, f1=0.6915
# epoch no 273, logloss=1.9425, f1=0.6889
# epoch no 274, logloss=1.9409, f1=0.6901
# epoch no 275, logloss=1.9368, f1=0.6928
# epoch no 276, logloss=1.9360, f1=0.6924
# epoch no 277, logloss=1.9381, f1=0.6890
# epoch no 278, logloss=1.9363, f1=0.6890
# epoch no 279, logloss=1.9313, f1=0.6916
# epoch no 280, logloss=1.9318, f1=0.6910
# epoch no 281, logloss=1.9322, f1=0.6913
# epoch no 282, logloss=1.9290, f1=0.6928
# epoch no 283, logloss=1.9291, f1=0.6916
# epoch no 284, logloss=1.9284, f1=0.6922
# epoch no 285, logloss=1.9301, f1=0.6921
# epoch no 286, logloss=1.9278, f1=0.6963
# epoch no 287, logloss=1.9214, f1=0.7015
# epoch no 288, logloss=1.9227, f1=0.6990
# epoch no 289, logloss=1.9206, f1=0.6982
# epoch no 290, logloss=1.9205, f1=0.6963
# epoch no 291, logloss=1.9225, f1=0.6937
# epoch no 292, logloss=1.9192, f1=0.6952
# epoch no 293, logloss=1.9198, f1=0.6940
# epoch no 294, logloss=1.9170, f1=0.6955
# epoch no 295, logloss=1.9134, f1=0.6972
# epoch no 296, logloss=1.9142, f1=0.6957
# epoch no 297, logloss=1.9128, f1=0.6972
# epoch no 298, logloss=1.9066, f1=0.7022
# epoch no 299, logloss=1.9085, f1=0.7012
# epoch no 300, logloss=1.9060, f1=0.7013
# epoch no 301, logloss=1.9051, f1=0.6998
# epoch no 302, logloss=1.9066, f1=0.6982
# epoch no 303, logloss=1.9033, f1=0.7002
# epoch no 304, logloss=1.9033, f1=0.7006
# epoch no 305, logloss=1.9023, f1=0.7017
# epoch no 306, logloss=1.8992, f1=0.7017
# epoch no 307, logloss=1.9031, f1=0.6983
# epoch no 308, logloss=1.8995, f1=0.7021
# epoch no 309, logloss=1.8964, f1=0.7045
# epoch no 310, logloss=1.8984, f1=0.7045
# epoch no 311, logloss=1.8899, f1=0.7093
# epoch no 312, logloss=1.8912, f1=0.7066
# epoch no 313, logloss=1.8937, f1=0.7022
# epoch no 314, logloss=1.8927, f1=0.7013
# epoch no 315, logloss=1.8933, f1=0.7016
# epoch no 316, logloss=1.8932, f1=0.7016
# epoch no 317, logloss=1.8920, f1=0.7015
# epoch no 318, logloss=1.8907, f1=0.7026
# epoch no 319, logloss=1.8877, f1=0.7047
# epoch no 320, logloss=1.8866, f1=0.7047
# epoch no 321, logloss=1.8867, f1=0.7043
# epoch no 322, logloss=1.8849, f1=0.7052
# epoch no 323, logloss=1.8834, f1=0.7052
# epoch no 324, logloss=1.8848, f1=0.7040
# epoch no 325, logloss=1.8843, f1=0.7041
# epoch no 326, logloss=1.8821, f1=0.7047
# epoch no 327, logloss=1.8853, f1=0.7019
# epoch no 328, logloss=1.8825, f1=0.7028
# epoch no 329, logloss=1.8802, f1=0.7055
# epoch no 330, logloss=1.8778, f1=0.7098
# epoch no 331, logloss=1.8727, f1=0.7140
# epoch no 332, logloss=1.8762, f1=0.7111
# epoch no 333, logloss=1.8760, f1=0.7090
# epoch no 334, logloss=1.8748, f1=0.7075
# epoch no 335, logloss=1.8780, f1=0.7053
# epoch no 336, logloss=1.8758, f1=0.7056
# epoch no 337, logloss=1.8770, f1=0.7057
# epoch no 338, logloss=1.8712, f1=0.7090
# epoch no 339, logloss=1.8696, f1=0.7100
# epoch no 340, logloss=1.8733, f1=0.7077
# epoch no 341, logloss=1.8688, f1=0.7098
# epoch no 342, logloss=1.8690, f1=0.7104
# epoch no 343, logloss=1.8697, f1=0.7102
# epoch no 344, logloss=1.8665, f1=0.7112
# epoch no 345, logloss=1.8660, f1=0.7105
# epoch no 346, logloss=1.8695, f1=0.7072
# epoch no 347, logloss=1.8665, f1=0.7091
# epoch no 348, logloss=1.8624, f1=0.7118
# epoch no 349, logloss=1.8653, f1=0.7100
# epoch no 350, logloss=1.8666, f1=0.7086
# epoch no 351, logloss=1.8650, f1=0.7091
# epoch no 352, logloss=1.8622, f1=0.7112
# epoch no 353, logloss=1.8615, f1=0.7134
# epoch no 354, logloss=1.8590, f1=0.7165
# epoch no 355, logloss=1.8569, f1=0.7175
# epoch no 356, logloss=1.8573, f1=0.7154
# epoch no 357, logloss=1.8590, f1=0.7139
# epoch no 358, logloss=1.8568, f1=0.7164
# epoch no 359, logloss=1.8545, f1=0.7184
# epoch no 360, logloss=1.8591, f1=0.7144
# epoch no 361, logloss=1.8557, f1=0.7159
# epoch no 362, logloss=1.8516, f1=0.7178
# epoch no 363, logloss=1.8553, f1=0.7148
# epoch no 364, logloss=1.8540, f1=0.7155
# epoch no 365, logloss=1.8534, f1=0.7161
# epoch no 366, logloss=1.8507, f1=0.7167
# epoch no 367, logloss=1.8525, f1=0.7135
# epoch no 368, logloss=1.8566, f1=0.7112
# epoch no 369, logloss=1.8483, f1=0.7176
# epoch no 370, logloss=1.8509, f1=0.7166
# epoch no 371, logloss=1.8497, f1=0.7175
# epoch no 372, logloss=1.8483, f1=0.7176
# epoch no 373, logloss=1.8518, f1=0.7144
# epoch no 374, logloss=1.8501, f1=0.7149
# epoch no 375, logloss=1.8468, f1=0.7178
# epoch no 376, logloss=1.8477, f1=0.7169
# epoch no 377, logloss=1.8486, f1=0.7149
# epoch no 378, logloss=1.8484, f1=0.7127
# epoch no 379, logloss=1.8491, f1=0.7128
# epoch no 380, logloss=1.8453, f1=0.7147
# epoch no 381, logloss=1.8479, f1=0.7142
# epoch no 382, logloss=1.8421, f1=0.7169
# epoch no 383, logloss=1.8432, f1=0.7153
# epoch no 384, logloss=1.8484, f1=0.7122
# epoch no 385, logloss=1.8396, f1=0.7180
# epoch no 386, logloss=1.8430, f1=0.7169
# epoch no 387, logloss=1.8404, f1=0.7192
# epoch no 388, logloss=1.8380, f1=0.7203
# epoch no 389, logloss=1.8411, f1=0.7175
# epoch no 390, logloss=1.8360, f1=0.7199
# epoch no 391, logloss=1.8400, f1=0.7172
# epoch no 392, logloss=1.8415, f1=0.7164
# epoch no 393, logloss=1.8374, f1=0.7189
# epoch no 394, logloss=1.8409, f1=0.7174
# epoch no 395, logloss=1.8358, f1=0.7193
# epoch no 396, logloss=1.8388, f1=0.7177
# epoch no 397, logloss=1.8322, f1=0.7222
# epoch no 398, logloss=1.8345, f1=0.7202
# epoch no 399, logloss=1.8389, f1=0.7169
# epoch no 400, logloss=1.8344, f1=0.7182
# epoch no 401, logloss=1.8384, f1=0.7162
# epoch no 402, logloss=1.8347, f1=0.7186
# epoch no 403, logloss=1.8331, f1=0.7202
# epoch no 404, logloss=1.8329, f1=0.7195
# epoch no 405, logloss=1.8335, f1=0.7173
# epoch no 406, logloss=1.8342, f1=0.7169
# epoch no 407, logloss=1.8308, f1=0.7199
# epoch no 408, logloss=1.8338, f1=0.7205
# epoch no 409, logloss=1.8257, f1=0.7277
# epoch no 410, logloss=1.8237, f1=0.7297
# epoch no 411, logloss=1.8241, f1=0.7279
# epoch no 412, logloss=1.8284, f1=0.7225
# epoch no 413, logloss=1.8291, f1=0.7209
# epoch no 414, logloss=1.8248, f1=0.7227
# epoch no 415, logloss=1.8302, f1=0.7203
# epoch no 416, logloss=1.8283, f1=0.7223
# epoch no 417, logloss=1.8247, f1=0.7249
# epoch no 418, logloss=1.8249, f1=0.7250
# epoch no 419, logloss=1.8244, f1=0.7249
# epoch no 420, logloss=1.8240, f1=0.7250
# epoch no 421, logloss=1.8236, f1=0.7239
# epoch no 422, logloss=1.8236, f1=0.7239
# epoch no 423, logloss=1.8222, f1=0.7245
# epoch no 424, logloss=1.8243, f1=0.7237
# epoch no 425, logloss=1.8221, f1=0.7244
# epoch no 426, logloss=1.8272, f1=0.7215
# epoch no 427, logloss=1.8228, f1=0.7259
# epoch no 428, logloss=1.8225, f1=0.7254
# epoch no 429, logloss=1.8269, f1=0.7232
# epoch no 430, logloss=1.8183, f1=0.7284
# epoch no 431, logloss=1.8183, f1=0.7287
# epoch no 432, logloss=1.8210, f1=0.7247
# epoch no 433, logloss=1.8224, f1=0.7238
# epoch no 434, logloss=1.8182, f1=0.7271
# epoch no 435, logloss=1.8171, f1=0.7287
# epoch no 436, logloss=1.8207, f1=0.7262
# epoch no 437, logloss=1.8133, f1=0.7312
# epoch no 438, logloss=1.8147, f1=0.7301
# epoch no 439, logloss=1.8181, f1=0.7260
# epoch no 440, logloss=1.8199, f1=0.7239
# epoch no 441, logloss=1.8178, f1=0.7259
# epoch no 442, logloss=1.8150, f1=0.7281
# epoch no 443, logloss=1.8158, f1=0.7282
# epoch no 444, logloss=1.8152, f1=0.7283
# epoch no 445, logloss=1.8152, f1=0.7280
# epoch no 446, logloss=1.8132, f1=0.7285
# epoch no 447, logloss=1.8163, f1=0.7272
# epoch no 448, logloss=1.8139, f1=0.7283
# epoch no 449, logloss=1.8117, f1=0.7297
# epoch no 450, logloss=1.8155, f1=0.7276
# epoch no 451, logloss=1.8104, f1=0.7295
# epoch no 452, logloss=1.8162, f1=0.7265
# epoch no 453, logloss=1.8104, f1=0.7292
# epoch no 454, logloss=1.8155, f1=0.7264
# epoch no 455, logloss=1.8097, f1=0.7307
# epoch no 456, logloss=1.8084, f1=0.7307
# epoch no 457, logloss=1.8127, f1=0.7290
# epoch no 458, logloss=1.8058, f1=0.7322
# epoch no 459, logloss=1.8127, f1=0.7299
# epoch no 460, logloss=1.8047, f1=0.7336
# epoch no 461, logloss=1.8151, f1=0.7278
# epoch no 462, logloss=1.8045, f1=0.7334
# epoch no 463, logloss=1.8056, f1=0.7336
# epoch no 464, logloss=1.8115, f1=0.7315
# epoch no 465, logloss=1.8009, f1=0.7376
# epoch no 466, logloss=1.8095, f1=0.7332
# epoch no 467, logloss=1.8046, f1=0.7337
# epoch no 468, logloss=1.8059, f1=0.7320
# epoch no 469, logloss=1.8085, f1=0.7307
# epoch no 470, logloss=1.8039, f1=0.7321
# epoch no 471, logloss=1.8074, f1=0.7305
# epoch no 472, logloss=1.8040, f1=0.7326
# epoch no 473, logloss=1.8036, f1=0.7330
# epoch no 474, logloss=1.8051, f1=0.7314
# epoch no 475, logloss=1.8051, f1=0.7318
# epoch no 476, logloss=1.8036, f1=0.7328
# epoch no 477, logloss=1.7994, f1=0.7353
# epoch no 478, logloss=1.8040, f1=0.7319
# epoch no 479, logloss=1.8011, f1=0.7343
# epoch no 480, logloss=1.7977, f1=0.7372
# epoch no 481, logloss=1.8029, f1=0.7331
# epoch no 482, logloss=1.8024, f1=0.7317
# epoch no 483, logloss=1.8029, f1=0.7314
# epoch no 484, logloss=1.8010, f1=0.7335
# epoch no 485, logloss=1.8011, f1=0.7328
# epoch no 486, logloss=1.8032, f1=0.7321
# epoch no 487, logloss=1.7980, f1=0.7359
# epoch no 488, logloss=1.7982, f1=0.7359
# epoch no 489, logloss=1.7983, f1=0.7356
# epoch no 490, logloss=1.8005, f1=0.7333
# epoch no 491, logloss=1.8004, f1=0.7327
# epoch no 492, logloss=1.7973, f1=0.7351
# epoch no 493, logloss=1.8007, f1=0.7340
# epoch no 494, logloss=1.7985, f1=0.7340
# epoch no 495, logloss=1.7996, f1=0.7340
# epoch no 496, logloss=1.7966, f1=0.7358
# epoch no 497, logloss=1.7952, f1=0.7355
# epoch no 498, logloss=1.8000, f1=0.7324
# epoch no 499, logloss=1.7932, f1=0.7358
# epoch no 500, logloss=1.7956, f1=0.7350
# epoch no 501, logloss=1.7984, f1=0.7336
# epoch no 502, logloss=1.7908, f1=0.7385
# epoch no 503, logloss=1.7943, f1=0.7378
# epoch no 504, logloss=1.7950, f1=0.7365
# epoch no 505, logloss=1.7986, f1=0.7344
# epoch no 506, logloss=1.7946, f1=0.7380
# epoch no 507, logloss=1.7918, f1=0.7401
# epoch no 508, logloss=1.7926, f1=0.7386
# epoch no 509, logloss=1.7899, f1=0.7399
# epoch no 510, logloss=1.7906, f1=0.7385
# epoch no 511, logloss=1.7975, f1=0.7341
# epoch no 512, logloss=1.7905, f1=0.7387
# epoch no 513, logloss=1.7900, f1=0.7399
# epoch no 514, logloss=1.7941, f1=0.7365
# epoch no 515, logloss=1.7942, f1=0.7347
# epoch no 516, logloss=1.7945, f1=0.7349
# epoch no 517, logloss=1.7907, f1=0.7367
# epoch no 518, logloss=1.7928, f1=0.7347
# epoch no 519, logloss=1.7957, f1=0.7329
# epoch no 520, logloss=1.7865, f1=0.7408
# epoch no 521, logloss=1.7886, f1=0.7396
# epoch no 522, logloss=1.7944, f1=0.7348
# epoch no 523, logloss=1.7906, f1=0.7372
# epoch no 524, logloss=1.7898, f1=0.7380
# epoch no 525, logloss=1.7930, f1=0.7357
# epoch no 526, logloss=1.7904, f1=0.7380
# epoch no 527, logloss=1.7858, f1=0.7416
# epoch no 528, logloss=1.7848, f1=0.7415
# epoch no 529, logloss=1.7912, f1=0.7367
# epoch no 530, logloss=1.7873, f1=0.7392
# epoch no 531, logloss=1.7868, f1=0.7399
# epoch no 532, logloss=1.7937, f1=0.7349
# epoch no 533, logloss=1.7875, f1=0.7380
# epoch no 534, logloss=1.7910, f1=0.7371
# epoch no 535, logloss=1.7867, f1=0.7403
# epoch no 536, logloss=1.7865, f1=0.7421
# epoch no 537, logloss=1.7851, f1=0.7420
# epoch no 538, logloss=1.7856, f1=0.7396
# epoch no 539, logloss=1.7861, f1=0.7399
# epoch no 540, logloss=1.7878, f1=0.7384
# epoch no 541, logloss=1.7877, f1=0.7386
# epoch no 542, logloss=1.7862, f1=0.7393
# epoch no 543, logloss=1.7846, f1=0.7401
# epoch no 544, logloss=1.7831, f1=0.7412
# epoch no 545, logloss=1.7879, f1=0.7391
# epoch no 546, logloss=1.7846, f1=0.7402
# epoch no 547, logloss=1.7883, f1=0.7379
# epoch no 548, logloss=1.7846, f1=0.7404
# epoch no 549, logloss=1.7831, f1=0.7427
# epoch no 550, logloss=1.7825, f1=0.7423
# epoch no 551, logloss=1.7845, f1=0.7402
# epoch no 552, logloss=1.7828, f1=0.7411
# epoch no 553, logloss=1.7856, f1=0.7382
# epoch no 554, logloss=1.7865, f1=0.7372
# epoch no 555, logloss=1.7839, f1=0.7401
# epoch no 556, logloss=1.7844, f1=0.7414
# epoch no 557, logloss=1.7813, f1=0.7442
# epoch no 558, logloss=1.7814, f1=0.7447
# epoch no 559, logloss=1.7811, f1=0.7437
# epoch no 560, logloss=1.7827, f1=0.7430
# epoch no 561, logloss=1.7752, f1=0.7492
# epoch no 562, logloss=1.7798, f1=0.7462
# epoch no 563, logloss=1.7832, f1=0.7421
# epoch no 564, logloss=1.7807, f1=0.7423
# epoch no 565, logloss=1.7869, f1=0.7378
# epoch no 566, logloss=1.7852, f1=0.7394
# epoch no 567, logloss=1.7801, f1=0.7430
# epoch no 568, logloss=1.7806, f1=0.7435
# epoch no 569, logloss=1.7745, f1=0.7491
# epoch no 570, logloss=1.7773, f1=0.7474
# epoch no 571, logloss=1.7797, f1=0.7431
# epoch no 572, logloss=1.7847, f1=0.7390
# epoch no 573, logloss=1.7813, f1=0.7412
# epoch no 574, logloss=1.7829, f1=0.7408
# epoch no 575, logloss=1.7850, f1=0.7390
# epoch no 576, logloss=1.7769, f1=0.7447
# epoch no 577, logloss=1.7811, f1=0.7419
# epoch no 578, logloss=1.7819, f1=0.7409
# epoch no 579, logloss=1.7766, f1=0.7449
# epoch no 580, logloss=1.7791, f1=0.7440
# epoch no 581, logloss=1.7814, f1=0.7406
# epoch no 582, logloss=1.7827, f1=0.7397
# epoch no 583, logloss=1.7797, f1=0.7404
# epoch no 584, logloss=1.7816, f1=0.7417
# epoch no 585, logloss=1.7728, f1=0.7488
# epoch no 586, logloss=1.7782, f1=0.7453
# epoch no 587, logloss=1.7806, f1=0.7418
# epoch no 588, logloss=1.7822, f1=0.7414
# epoch no 589, logloss=1.7783, f1=0.7426
# epoch no 590, logloss=1.7815, f1=0.7406
# epoch no 591, logloss=1.7811, f1=0.7405
# epoch no 592, logloss=1.7781, f1=0.7407
# epoch no 593, logloss=1.7816, f1=0.7394
# epoch no 594, logloss=1.7762, f1=0.7442
# epoch no 595, logloss=1.7759, f1=0.7441
# epoch no 596, logloss=1.7831, f1=0.7386
# epoch no 597, logloss=1.7747, f1=0.7450
# epoch no 598, logloss=1.7781, f1=0.7452
# epoch no 599, logloss=1.7728, f1=0.7498
# fold 2, took 8420.984s

# %%
nn_oof_train_pred = np.zeros(y_train.shape, dtype='float32')

for i, (train_idx, val_idx) in enumerate(cv):
    nn_oof_train_pred[val_idx] = train_preds[i]

# %%
nn_oof_train_pred.shape
# Out:
# (177350, 139)

# %%
for t in np.linspace(0, 1, 21):
    f = f1_score(y_train, nn_oof_train_pred >= t, average='micro')
    print('t=%0.2f, f1=%0.4f' % (t, f))
# Out:
# t=0.00, f1=0.0205
# t=0.05, f1=0.6686
# t=0.10, f1=0.7299
# t=0.15, f1=0.7545
# t=0.20, f1=0.7662
# t=0.25, f1=0.7708
# t=0.30, f1=0.7710
# t=0.35, f1=0.7683
# t=0.40, f1=0.7632
# t=0.45, f1=0.7563
# t=0.50, f1=0.7479
# t=0.55, f1=0.7374
# t=0.60, f1=0.7249
# t=0.65, f1=0.7097
# t=0.70, f1=0.6921
# t=0.75, f1=0.6705
# t=0.80, f1=0.6438
# t=0.85, f1=0.6082
# t=0.90, f1=0.5574
# t=0.95, f1=0.4718
# t=1.00, f1=0.0022

# %%
nn_test_pred = np.mean(test_preds, axis=0)

# %%
with open('nn_preds_all.bin', 'wb') as f:
    pickle.dump((nn_oof_train_pred, nn_test_pred), f)

# %%
with open('nn_preds_all.bin', 'rb') as f:
    nn_oof_train_pred, nn_test_pred = pickle.load(f)

# %%
test_preds = dict(zip(selected_topics, (nn_test_pred >= 0.3).astype('uint8').T))

# %%
all_zeros = np.zeros(len(df_test), dtype='uint8')

df_final_pred = pd.DataFrame()
df_final_pred['id'] = df_test['key']

for t in all_topics:
    if t in test_preds:
        df_final_pred[t] = test_preds[t]
    else:
        df_final_pred[t] = all_zeros

# %%
df_final_pred.to_csv('nn.csv', index=False)
